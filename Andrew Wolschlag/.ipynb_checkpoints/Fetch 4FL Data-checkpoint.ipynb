# %%
from ESPNAPI import League
import pprint

# year = "2021"
# leagueID = "2132617421"
# espn_s2 = "AEBlmW%2BnPlQPu68%2B3lzmpbsb5hNTRKEtHrL%2Bq8FkioyJ%2BAkHtJm7yYEagGmtwT%2BH4Wb9lhRdwJzDvYyDuUQ8huceOylAFUJtO3MVkxn0EsDJk47eyalQUduQyirWQiRoByYOp%2Bjhc8pG4Gfi2KftR2%2FBXgElrd734Lz0TBXCYDb33tB3PQt8S1Q6GcdZZ757%2BMeBz%2Fd87XfRCkn3Kgs%2FnB40EJtzL30SlEPeKBmB%2ByUdrysHbYZz9ESlKSIkBuey92sudtrZvPf5NUAIoAOmX2Py7fM1V1E%2F0zHImDLRUcar%2Bw%3D%3D"
# swid = "{9AED192A-A64B-4ECA-9772-BDDE2396067C}"

year = "2020"
leagueID = "139889"
espn_s2 = "AEBVAY4IP16BsQVvRgpY1hGOur4OKjZCVh6vfBIibHEoA5BHQCg3rZGBvbNbuESU3bQlfQzdveoAqNcmIhoBoO10gq2K%2FOhtdYamn6aQBihs%2FydsgoJehuJgLwAIdcaXlnehxcpTltR58fP0cX18vjZReJjo0OjZGUSOr3ff0Iuz1Ztt8c4rUkFJVTd8cEd%2BT76%2Bvva8s5iQGAfKTUfPA9P2k6xC33qYcaH%2FIYykwIC00PKoJOlysod9yM5bUrA39lpJ2WZQfdICgqXt5zu%2FYaDpiXVznvExI4BIoEFnEVfs3w%3D%3D"
swid = "{65C194B8-D67C-4A07-8990-988E5F391434}"

My_League = League(year, leagueID, espn_s2, swid)

reader = pprint.PrettyPrinter()
#pd.DataFrame.from_dict(IAA_League.fetch_teams(), orient = 'index')
print("--Teams--")
reader.pprint(My_League.fetch_teams())
print("--Rosters--")
reader.pprint(My_League.fetch_rosters())
print("--Matchups--")
reader.pprint(My_League.fetch_matchups())
print("--Matchup Rosters--")
reader.pprint(My_League.fetch_matchup_rosters())
# Out:
# --Teams--
# {1: {'acquisitions': 30,
#      'drops': 27,
#      'ownerNames': 'Adam Boghosian, noah henley',
#      'pointsAgainst': 1117.5,
#      'pointsFor': 955.5,
#      'record': '4-0-8',
#      'teamName': 'PEAKY PUGGLES',
#      'trades': 6,
#      'winPercentage': 0.3333333333333333},
#  2: {'acquisitions': 31,
#      'drops': 32,
#      'ownerNames': 'Andrew Wolschlag',
#      'pointsAgainst': 1070.0,
#      'pointsFor': 1094.0,
#      'record': '6-0-6',
#      'teamName': 'Pickle Ricks',
#      'trades': 1,
#      'winPercentage': 0.5},
#  3: {'acquisitions': 32,
#      'drops': 28,
#      'ownerNames': 'Alvin Ong',
#      'pointsAgainst': 1045.0,
#      'pointsFor': 1365.0,
#      'record': '12-0-0',
#      'teamName': 'Emperor Vin',
#      'trades': 7,
#      'winPercentage': 1.0},
#  4: {'acquisitions': 25,
#      'drops': 25,
#      'ownerNames': 'Priyank Purohit',
#      'pointsAgainst': 1067.5,
#      'pointsFor': 1313.0,
#      'record': '8-0-4',
#      'teamName': 'Bollywood Beast Mode',
#      'trades': 2,
#      'winPercentage': 0.6666666666666666},
#  5: {'acquisitions': 8,
#      'drops': 7,
#      'ownerNames': 'Kyle Griffin, Troy Blaser',
#      'pointsAgainst': 1151.5,
#      'pointsFor': 1182.0,
#      'record': '6-0-6',
#      'teamName': 'Haha Clinton "Hold Muh" Dix',
#      'trades': 1,
#      'winPercentage': 0.5},
#  6: {'acquisitions': 23,
#      'drops': 22,
#      'ownerNames': 'Wesley Clark',
#      'pointsAgainst': 1185.0,
#      'pointsFor': 1161.0,
#      'record': '4-0-8',
#      'teamName': 'The 4FLs Punching Bag',
#      'trades': 0,
#      'winPercentage': 0.3333333333333333},
#  7: {'acquisitions': 41,
#      'drops': 40,
#      'ownerNames': 'Brian Rauf',
#      'pointsAgainst': 1215.5,
#      'pointsFor': 904.5,
#      'record': '2-0-10',
#      'teamName': 'Suburban Dad',
#      'trades': 3,
#      'winPercentage': 0.16666666666666666},
#  8: {'acquisitions': 9,
#      'drops': 6,
#      'ownerNames': 'Sam Rossabi',
#      'pointsAgainst': 1096.0,
#      'pointsFor': 1021.0,
#      'record': '6-0-6',
#      'teamName': 'Goonfield Gnarbarians',
#      'trades': 1,
#      'winPercentage': 0.5},
#  9: {'acquisitions': 6,
#      'drops': 6,
#      'ownerNames': 'james earle, Daniel Christan',
#      'pointsAgainst': 1146.0,
#      'pointsFor': 962.0,
#      'record': '3-0-9',
#      'teamName': 'Hurst Jmearles ',
#      'trades': 2,
#      'winPercentage': 0.25},
#  10: {'acquisitions': 17,
#       'drops': 16,
#       'ownerNames': 'sean walsh',
#       'pointsAgainst': 1184.0,
#       'pointsFor': 1338.0,
#       'record': '8-0-4',
#       'teamName': 'Kibbls And Vick',
#       'trades': 1,
#       'winPercentage': 0.6666666666666666},
#  11: {'acquisitions': 25,
#       'drops': 21,
#       'ownerNames': 'Brad Snipes',
#       'pointsAgainst': 998.5,
#       'pointsFor': 1154.5,
#       'record': '8-0-4',
#       'teamName': 'Scared Turtle',
#       'trades': 3,
#       'winPercentage': 0.6666666666666666},
#  12: {'acquisitions': 56,
#       'drops': 55,
#       'ownerNames': 'Matt Peterson',
#       'pointsAgainst': 1180.0,
#       'pointsFor': 1006.0,
#       'record': '5-0-7',
#       'teamName': 'Wall Street Pete',
#       'trades': 3,
#       'winPercentage': 0.4166666666666667}}
# --Rosters--
# {1: {'defaultPosition': ['RB/WR',
#                          'RB',
#                          'TQB',
#                          'D/ST',
#                          'RB',
#                          'RB',
#                          'RB/WR',
#                          'WR',
#                          'RB',
#                          'RB/WR',
#                          'RB',
#                          'RB',
#                          'WR',
#                          'WR/TE',
#                          'RB',
#                          'TQB'],
#      'roster': ['DJ Chark Jr.',
#                 'Melvin Gordon III',
#                 'Cam Newton',
#                 'Cardinals D/ST',
#                 'Myles Gaskin',
#                 'Mike Davis',
#                 'Justin Jefferson',
#                 'Hunter Henry',
#                 'Ezekiel Elliott',
#                 'Antonio Brown',
#                 'J.D. McKissic',
#                 'Devonta Freeman',
#                 'Logan Thomas',
#                 'Jason Myers',
#                 'DeAndre Washington',
#                 'Jared Goff']},
#  2: {'defaultPosition': ['TQB',
#                          'WR',
#                          'RB/WR',
#                          'RB/WR',
#                          'RB',
#                          'RB/WR',
#                          'RB',
#                          'WR',
#                          'D/ST',
#                          'TQB',
#                          'RB',
#                          'RB',
#                          'WR/TE',
#                          'WR'],
#      'roster': ['Lamar Jackson',
#                 'Zach Ertz',
#                 'Davante Adams',
#                 'Keenan Allen',
#                 'Raheem Mostert',
#                 'Robby Anderson',
#                 'David Montgomery',
#                 'Hayden Hurst',
#                 'Bears D/ST',
#                 'Justin Herbert',
#                 'Jamaal Williams',
#                 'J.K. Dobbins',
#                 'Stephen Gostkowski',
#                 'Gerald Everett']},
#  3: {'defaultPosition': ['RB',
#                          'RB/WR',
#                          'TQB',
#                          'WR/TE',
#                          'WR',
#                          'RB/WR',
#                          'WR',
#                          'RB',
#                          'RB',
#                          'RB/WR',
#                          'RB',
#                          'WR/TE',
#                          'D/ST',
#                          'D/ST'],
#      'roster': ['Dalvin Cook',
#                 'Adam Thielen',
#                 'Kyler Murray',
#                 'Justin Tucker',
#                 'Jonnu Smith',
#                 'Tyler Lockett',
#                 'Dallas Goedert',
#                 'Chase Edmonds',
#                 'Nick Chubb',
#                 'DeAndre Hopkins',
#                 'Damien Harris',
#                 'Harrison Butker',
#                 '49ers D/ST',
#                 'Bills D/ST']},
#  4: {'defaultPosition': ['RB',
#                          'RB',
#                          'WR',
#                          'RB/WR',
#                          'RB/WR',
#                          'TQB',
#                          'RB',
#                          'RB/WR',
#                          'WR',
#                          'RB',
#                          'TQB',
#                          'D/ST',
#                          'RB/WR',
#                          'WR/TE'],
#      'roster': ['Alvin Kamara',
#                 'Christian McCaffrey',
#                 'Travis Kelce',
#                 'Cooper Kupp',
#                 'Terry McLaurin',
#                 'Aaron Rodgers',
#                 'Zack Moss',
#                 'Chris Godwin',
#                 'T.J. Hockenson',
#                 'Clyde Edwards-Helaire',
#                 'Ben Roethlisberger',
#                 'Dolphins D/ST',
#                 'Deebo Samuel',
#                 'Joey Slye']},
#  5: {'defaultPosition': ['RB',
#                          'RB/WR',
#                          'RB',
#                          'RB/WR',
#                          'WR',
#                          'RB/WR',
#                          'TQB',
#                          'RB/WR',
#                          'D/ST',
#                          'RB/WR',
#                          'RB',
#                          'WR',
#                          'WR/TE',
#                          'TQB',
#                          'D/ST'],
#      'roster': ['Miles Sanders',
#                 'Allen Robinson II',
#                 'David Johnson',
#                 'DK Metcalf',
#                 'Evan Engram',
#                 'Brandin Cooks',
#                 'Matt Ryan',
#                 'John Brown',
#                 'Ravens D/ST',
#                 'Curtis Samuel',
#                 'James Robinson',
#                 'George Kittle',
#                 'Wil Lutz',
#                 'Taysom Hill',
#                 'Chiefs D/ST']},
#  6: {'defaultPosition': ['RB',
#                          'RB',
#                          'RB/WR',
#                          'RB/WR',
#                          'WR',
#                          'RB/WR',
#                          'RB',
#                          'RB',
#                          'RB',
#                          'WR/TE',
#                          'RB/WR',
#                          'TQB',
#                          'WR',
#                          'D/ST',
#                          'D/ST'],
#      'roster': ['Saquon Barkley',
#                 'Derrick Henry',
#                 'JuJu Smith-Schuster',
#                 'Kenny Golladay',
#                 'Mark Andrews',
#                 'Calvin Ridley',
#                 'Kareem Hunt',
#                 'Antonio Gibson',
#                 'Jerick McKinnon',
#                 'Jason Sanders',
#                 'Christian Kirk',
#                 'Kirk Cousins',
#                 'Robert Tonyan',
#                 'Chargers D/ST',
#                 'Vikings D/ST']},
#  7: {'defaultPosition': ['RB',
#                          'RB',
#                          'WR/TE',
#                          'D/ST',
#                          'RB/WR',
#                          'RB/WR',
#                          'RB',
#                          'D/ST',
#                          'TQB',
#                          'RB/WR',
#                          'TQB',
#                          'TQB',
#                          'WR',
#                          'WR'],
#      'roster': ['Leonard Fournette',
#                 'Jonathan Taylor',
#                 'Rodrigo Blankenship',
#                 'Colts D/ST',
#                 'Tee Higgins',
#                 'CeeDee Lamb',
#                 'Wayne Gallman',
#                 'Seahawks D/ST',
#                 'Derek Carr',
#                 'Corey Davis',
#                 'Tua Tagovailoa',
#                 'Jalen Hurts',
#                 'Jared Cook',
#                 'Mike Gesicki']},
#  8: {'defaultPosition': ['TQB',
#                          'RB',
#                          'RB/WR',
#                          'RB/WR',
#                          'RB/WR',
#                          'WR',
#                          'D/ST',
#                          'RB/WR',
#                          'RB',
#                          'TQB',
#                          'RB/WR',
#                          'WR',
#                          'WR/TE',
#                          'RB',
#                          'RB/WR'],
#      'roster': ['Dak Prescott',
#                 'Kenyan Drake',
#                 'Robert Woods',
#                 'Stefon Diggs',
#                 'Preston Williams',
#                 'Austin Hooper',
#                 'Broncos D/ST',
#                 'Sammy Watkins',
#                 'Nyheim Hines',
#                 'Ryan Tannehill',
#                 'DJ Moore',
#                 'Jimmy Graham',
#                 'Matt Prater',
#                 'Rex Burkhead',
#                 'Marquise Brown']},
#  9: {'defaultPosition': ['RB/WR',
#                          'RB',
#                          'RB',
#                          'RB',
#                          'RB/WR',
#                          'WR/TE',
#                          'RB',
#                          'WR',
#                          'RB',
#                          'TQB',
#                          'RB/WR',
#                          'D/ST',
#                          'WR',
#                          'WR/TE',
#                          'RB'],
#      'roster': ['Mike Evans',
#                 'James Conner',
#                 'James White',
#                 'Darrell Henderson Jr.',
#                 'DeSean Jackson',
#                 'Robbie Gould',
#                 'Austin Ekeler',
#                 'Tyler Higbee',
#                 "Le'Veon Bell",
#                 'Deshaun Watson',
#                 'Darius Slayton',
#                 'Browns D/ST',
#                 'Eric Ebron',
#                 'Michael Badgley',
#                 'Benny Snell Jr.']},
#  10: {'defaultPosition': ['RB/WR',
#                           'RB',
#                           'RB',
#                           'RB',
#                           'RB/WR',
#                           'TQB',
#                           'RB/WR',
#                           'D/ST',
#                           'WR',
#                           'WR/TE',
#                           'RB',
#                           'RB',
#                           'RB',
#                           'RB/WR',
#                           'RB/WR'],
#       'roster': ['Tyreek Hill',
#                  'Joe Mixon',
#                  'Aaron Jones',
#                  'Todd Gurley II',
#                  'Jarvis Landry',
#                  'Russell Wilson',
#                  'Jamison Crowder',
#                  'Steelers D/ST',
#                  'Rob Gronkowski',
#                  'Younghoe Koo',
#                  'Giovani Bernard',
#                  'Duke Johnson',
#                  'Kalen Ballage',
#                  'Keke Coutee',
#                  'Marvin Jones Jr.']},
#  11: {'defaultPosition': ['RB/WR',
#                           'RB',
#                           'RB/WR',
#                           'RB',
#                           'RB/WR',
#                           'WR',
#                           'TQB',
#                           'TQB',
#                           'WR/TE',
#                           'RB/WR',
#                           'RB',
#                           'RB/WR',
#                           'RB/WR',
#                           'D/ST',
#                           'D/ST',
#                           'WR/TE'],
#       'roster': ['Julio Jones',
#                  'Josh Jacobs',
#                  'A.J. Brown',
#                  "D'Andre Swift",
#                  'Diontae Johnson',
#                  'Darren Waller',
#                  'Tom Brady',
#                  'Josh Allen',
#                  'Daniel Carlson',
#                  'Michael Thomas',
#                  'Cam Akers',
#                  'T.Y. Hilton',
#                  'Emmanuel Sanders',
#                  'Buccaneers D/ST',
#                  'Saints D/ST',
#                  'Cairo Santos']},
#  12: {'defaultPosition': ['TQB',
#                           'RB',
#                           'WR',
#                           'RB/WR',
#                           'RB/WR',
#                           'RB',
#                           'RB/WR',
#                           'RB/WR',
#                           'D/ST',
#                           'WR/TE',
#                           'RB',
#                           'RB/WR',
#                           'RB'],
#       'roster': ['Patrick Mahomes',
#                  'Ronald Jones II',
#                  'Noah Fant',
#                  'Jerry Jeudy',
#                  'Chase Claypool',
#                  'Chris Carson',
#                  'Amari Cooper',
#                  'Jakobi Meyers',
#                  'Washington D/ST',
#                  'Tyler Bass',
#                  'Devontae Booker',
#                  'Brandon Aiyuk',
#                  'Jeff Wilson Jr.']}}
# --Matchups--
# {1: {'awayScore': 67.5,
#      'awayTeamId': 9,
#      'homeScore': 75.0,
#      'homeTeamId': 12,
#      'week': 1,
#      'winner': 12},
#  2: {'awayScore': 112.5,
#      'awayTeamId': 5,
#      'homeScore': 129.5,
#      'homeTeamId': 6,
#      'week': 1,
#      'winner': 6},
#  3: {'awayScore': 103.5,
#      'awayTeamId': 10,
#      'homeScore': 75.5,
#      'homeTeamId': 8,
#      'week': 1,
#      'winner': 10},
#  4: {'awayScore': 125.5,
#      'awayTeamId': 4,
#      'homeScore': 81.0,
#      'homeTeamId': 1,
#      'week': 1,
#      'winner': 4},
#  5: {'awayScore': 68.5,
#      'awayTeamId': 7,
#      'homeScore': 114.5,
#      'homeTeamId': 11,
#      'week': 1,
#      'winner': 11},
#  6: {'awayScore': 111.5,
#      'awayTeamId': 3,
#      'homeScore': 102.5,
#      'homeTeamId': 2,
#      'week': 1,
#      'winner': 3},
#  7: {'awayScore': 109.0,
#      'awayTeamId': 5,
#      'homeScore': 88.5,
#      'homeTeamId': 9,
#      'week': 2,
#      'winner': 5},
#  8: {'awayScore': 75.5,
#      'awayTeamId': 12,
#      'homeScore': 145.5,
#      'homeTeamId': 10,
#      'week': 2,
#      'winner': 10},
#  9: {'awayScore': 65.5,
#      'awayTeamId': 6,
#      'homeScore': 127.5,
#      'homeTeamId': 4,
#      'week': 2,
#      'winner': 4},
#  10: {'awayScore': 117.0,
#       'awayTeamId': 8,
#       'homeScore': 68.5,
#       'homeTeamId': 7,
#       'week': 2,
#       'winner': 8},
#  11: {'awayScore': 99.5,
#       'awayTeamId': 1,
#       'homeScore': 137.0,
#       'homeTeamId': 3,
#       'week': 2,
#       'winner': 3},
#  12: {'awayScore': 85.5,
#       'awayTeamId': 11,
#       'homeScore': 67.5,
#       'homeTeamId': 2,
#       'week': 2,
#       'winner': 11},
#  13: {'awayScore': 126.0,
#       'awayTeamId': 9,
#       'homeScore': 107.0,
#       'homeTeamId': 10,
#       'week': 3,
#       'winner': 9},
#  14: {'awayScore': 138.0,
#       'awayTeamId': 4,
#       'homeScore': 88.5,
#       'homeTeamId': 5,
#       'week': 3,
#       'winner': 4},
#  15: {'awayScore': 82.5,
#       'awayTeamId': 7,
#       'homeScore': 106.0,
#       'homeTeamId': 12,
#       'week': 3,
#       'winner': 12},
#  16: {'awayScore': 138.0,
#       'awayTeamId': 3,
#       'homeScore': 115.5,
#       'homeTeamId': 6,
#       'week': 3,
#       'winner': 3},
#  17: {'awayScore': 69.0,
#       'awayTeamId': 2,
#       'homeScore': 96.0,
#       'homeTeamId': 8,
#       'week': 3,
#       'winner': 8},
#  18: {'awayScore': 85.5,
#       'awayTeamId': 11,
#       'homeScore': 81.0,
#       'homeTeamId': 1,
#       'week': 3,
#       'winner': 11},
#  19: {'awayScore': 113.0,
#       'awayTeamId': 4,
#       'homeScore': 56.5,
#       'homeTeamId': 9,
#       'week': 4,
#       'winner': 4},
#  20: {'awayScore': 123.5,
#       'awayTeamId': 10,
#       'homeScore': 103.5,
#       'homeTeamId': 7,
#       'week': 4,
#       'winner': 10},
#  21: {'awayScore': 104.0,
#       'awayTeamId': 5,
#       'homeScore': 105.5,
#       'homeTeamId': 3,
#       'week': 4,
#       'winner': 3},
#  22: {'awayScore': 81.0,
#       'awayTeamId': 12,
#       'homeScore': 78.5,
#       'homeTeamId': 2,
#       'week': 4,
#       'winner': 12},
#  23: {'awayScore': 90.0,
#       'awayTeamId': 6,
#       'homeScore': 110.5,
#       'homeTeamId': 11,
#       'week': 4,
#       'winner': 11},
#  24: {'awayScore': 89.5,
#       'awayTeamId': 8,
#       'homeScore': 87.0,
#       'homeTeamId': 1,
#       'week': 4,
#       'winner': 8},
#  25: {'awayScore': 104.5,
#       'awayTeamId': 9,
#       'homeScore': 81.5,
#       'homeTeamId': 7,
#       'week': 5,
#       'winner': 9},
#  26: {'awayScore': 130.0,
#       'awayTeamId': 3,
#       'homeScore': 83.0,
#       'homeTeamId': 4,
#       'week': 5,
#       'winner': 3},
#  27: {'awayScore': 80.5,
#       'awayTeamId': 2,
#       'homeScore': 102.0,
#       'homeTeamId': 10,
#       'week': 5,
#       'winner': 10},
#  28: {'awayScore': 78.0,
#       'awayTeamId': 11,
#       'homeScore': 111.5,
#       'homeTeamId': 5,
#       'week': 5,
#       'winner': 5},
#  29: {'awayScore': 109.5,
#       'awayTeamId': 1,
#       'homeScore': 80.5,
#       'homeTeamId': 12,
#       'week': 5,
#       'winner': 1},
#  30: {'awayScore': 85.5,
#       'awayTeamId': 8,
#       'homeScore': 116.0,
#       'homeTeamId': 6,
#       'week': 5,
#       'winner': 6},
#  31: {'awayScore': 111.5,
#       'awayTeamId': 3,
#       'homeScore': 79.0,
#       'homeTeamId': 9,
#       'week': 6,
#       'winner': 3},
#  32: {'awayScore': 77.0,
#       'awayTeamId': 7,
#       'homeScore': 79.5,
#       'homeTeamId': 2,
#       'week': 6,
#       'winner': 2},
#  33: {'awayScore': 68.0,
#       'awayTeamId': 4,
#       'homeScore': 123.5,
#       'homeTeamId': 11,
#       'week': 6,
#       'winner': 11},
#  34: {'awayScore': 92.0,
#       'awayTeamId': 10,
#       'homeScore': 100.0,
#       'homeTeamId': 1,
#       'week': 6,
#       'winner': 1},
#  35: {'awayScore': 107.0,
#       'awayTeamId': 5,
#       'homeScore': 98.5,
#       'homeTeamId': 8,
#       'week': 6,
#       'winner': 5},
#  36: {'awayScore': 99.5,
#       'awayTeamId': 12,
#       'homeScore': 99.0,
#       'homeTeamId': 6,
#       'week': 6,
#       'winner': 12},
#  37: {'awayScore': 69.5,
#       'awayTeamId': 9,
#       'homeScore': 134.0,
#       'homeTeamId': 2,
#       'week': 7,
#       'winner': 2},
#  38: {'awayScore': 85.0,
#       'awayTeamId': 11,
#       'homeScore': 126.0,
#       'homeTeamId': 3,
#       'week': 7,
#       'winner': 3},
#  39: {'awayScore': 57.5,
#       'awayTeamId': 1,
#       'homeScore': 96.0,
#       'homeTeamId': 7,
#       'week': 7,
#       'winner': 7},
#  40: {'awayScore': 45.0,
#       'awayTeamId': 8,
#       'homeScore': 121.0,
#       'homeTeamId': 4,
#       'week': 7,
#       'winner': 4},
#  41: {'awayScore': 96.0,
#       'awayTeamId': 6,
#       'homeScore': 110.5,
#       'homeTeamId': 10,
#       'week': 7,
#       'winner': 10},
#  42: {'awayScore': 52.5,
#       'awayTeamId': 12,
#       'homeScore': 114.5,
#       'homeTeamId': 5,
#       'week': 7,
#       'winner': 5},
#  43: {'awayScore': 87.0,
#       'awayTeamId': 11,
#       'homeScore': 63.5,
#       'homeTeamId': 9,
#       'week': 8,
#       'winner': 11},
#  44: {'awayScore': 98.0,
#       'awayTeamId': 2,
#       'homeScore': 59.5,
#       'homeTeamId': 1,
#       'week': 8,
#       'winner': 2},
#  45: {'awayScore': 96.5,
#       'awayTeamId': 3,
#       'homeScore': 79.5,
#       'homeTeamId': 8,
#       'week': 8,
#       'winner': 3},
#  46: {'awayScore': 64.5,
#       'awayTeamId': 7,
#       'homeScore': 48.0,
#       'homeTeamId': 6,
#       'week': 8,
#       'winner': 7},
#  47: {'awayScore': 101.5,
#       'awayTeamId': 4,
#       'homeScore': 92.5,
#       'homeTeamId': 12,
#       'week': 8,
#       'winner': 4},
#  48: {'awayScore': 126.5,
#       'awayTeamId': 10,
#       'homeScore': 113.5,
#       'homeTeamId': 5,
#       'week': 8,
#       'winner': 10},
#  49: {'awayScore': 54.5,
#       'awayTeamId': 9,
#       'homeScore': 58.5,
#       'homeTeamId': 1,
#       'week': 9,
#       'winner': 1},
#  50: {'awayScore': 61.5,
#       'awayTeamId': 8,
#       'homeScore': 105.0,
#       'homeTeamId': 11,
#       'week': 9,
#       'winner': 11},
#  51: {'awayScore': 74.5,
#       'awayTeamId': 6,
#       'homeScore': 105.5,
#       'homeTeamId': 2,
#       'week': 9,
#       'winner': 2},
#  52: {'awayScore': 87.5,
#       'awayTeamId': 12,
#       'homeScore': 110.0,
#       'homeTeamId': 3,
#       'week': 9,
#       'winner': 3},
#  53: {'awayScore': 102.5,
#       'awayTeamId': 5,
#       'homeScore': 65.0,
#       'homeTeamId': 7,
#       'week': 9,
#       'winner': 5},
#  54: {'awayScore': 96.5,
#       'awayTeamId': 10,
#       'homeScore': 133.5,
#       'homeTeamId': 4,
#       'week': 9,
#       'winner': 4},
#  55: {'awayScore': 89.0,
#       'awayTeamId': 8,
#       'homeScore': 65.0,
#       'homeTeamId': 9,
#       'week': 10,
#       'winner': 8},
#  56: {'awayScore': 72.5,
#       'awayTeamId': 1,
#       'homeScore': 78.0,
#       'homeTeamId': 6,
#       'week': 10,
#       'winner': 6},
#  57: {'awayScore': 115.0,
#       'awayTeamId': 11,
#       'homeScore': 68.0,
#       'homeTeamId': 12,
#       'week': 10,
#       'winner': 11},
#  58: {'awayScore': 83.0,
#       'awayTeamId': 2,
#       'homeScore': 52.0,
#       'homeTeamId': 5,
#       'week': 10,
#       'winner': 2},
#  59: {'awayScore': 107.0,
#       'awayTeamId': 3,
#       'homeScore': 67.0,
#       'homeTeamId': 10,
#       'week': 10,
#       'winner': 3},
#  60: {'awayScore': 79.5,
#       'awayTeamId': 7,
#       'homeScore': 107.5,
#       'homeTeamId': 4,
#       'week': 10,
#       'winner': 4},
#  61: {'awayScore': 108.0,
#       'awayTeamId': 9,
#       'homeScore': 96.0,
#       'homeTeamId': 6,
#       'week': 11,
#       'winner': 9},
#  62: {'awayScore': 78.0,
#       'awayTeamId': 12,
#       'homeScore': 99.5,
#       'homeTeamId': 8,
#       'week': 11,
#       'winner': 8},
#  63: {'awayScore': 71.0,
#       'awayTeamId': 5,
#       'homeScore': 92.5,
#       'homeTeamId': 1,
#       'week': 11,
#       'winner': 1},
#  64: {'awayScore': 103.0,
#       'awayTeamId': 10,
#       'homeScore': 90.0,
#       'homeTeamId': 11,
#       'week': 11,
#       'winner': 10},
#  65: {'awayScore': 100.5,
#       'awayTeamId': 4,
#       'homeScore': 113.0,
#       'homeTeamId': 2,
#       'week': 11,
#       'winner': 2},
#  66: {'awayScore': 67.5,
#       'awayTeamId': 7,
#       'homeScore': 102.0,
#       'homeTeamId': 3,
#       'week': 11,
#       'winner': 3},
#  79: {'awayScore': 83.0,
#       'awayTeamId': 2,
#       'homeScore': 161.0,
#       'homeTeamId': 10,
#       'week': 12,
#       'winner': 10},
#  80: {'awayScore': 94.0,
#       'awayTeamId': 4,
#       'homeScore': 96.0,
#       'homeTeamId': 5,
#       'week': 12,
#       'winner': 5},
#  81: {'awayScore': 79.5,
#       'awayTeamId': 9,
#       'homeScore': 84.5,
#       'homeTeamId': 8,
#       'week': 12,
#       'winner': 8},
#  82: {'awayScore': 90.0,
#       'awayTeamId': 3,
#       'homeScore': 75.0,
#       'homeTeamId': 11,
#       'week': 12,
#       'winner': 3},
#  83: {'awayScore': 153.0,
#       'awayTeamId': 6,
#       'homeScore': 50.5,
#       'homeTeamId': 7,
#       'week': 12,
#       'winner': 6},
#  84: {'awayScore': 57.0,
#       'awayTeamId': 1,
#       'homeScore': 110.0,
#       'homeTeamId': 12,
#       'week': 12,
#       'winner': 12},
#  85: {'awayScore': 149.0,
#       'awayTeamId': 5,
#       'homeScore': 216.0,
#       'homeTeamId': 3,
#       'week': 13,
#       'winner': 3},
#  86: {'awayScore': 213.0,
#       'awayTeamId': 11,
#       'homeScore': 160.0,
#       'homeTeamId': 10,
#       'week': 13,
#       'winner': 11},
#  87: {'awayScore': 203.5,
#       'awayTeamId': 2,
#       'homeScore': 165.5,
#       'homeTeamId': 8,
#       'week': 13,
#       'winner': 2},
#  88: {'awayScore': 174.0,
#       'awayTeamId': 12,
#       'homeScore': 212.0,
#       'homeTeamId': 4,
#       'week': 13,
#       'winner': 4},
#  89: {'awayScore': 203.0,
#       'awayTeamId': 7,
#       'homeScore': 204.0,
#       'homeTeamId': 6,
#       'week': 13,
#       'winner': 6},
#  90: {'awayScore': 178.0,
#       'awayTeamId': 1,
#       'homeScore': 94.5,
#       'homeTeamId': 9,
#       'week': 13,
#       'winner': 1},
#  91: {'awayScore': 222.5,
#       'awayTeamId': 11,
#       'homeScore': 218.0,
#       'homeTeamId': 3,
#       'week': 14,
#       'winner': 11},
#  92: {'awayScore': 201.0,
#       'awayTeamId': 5,
#       'homeScore': 186.5,
#       'homeTeamId': 10,
#       'week': 14,
#       'winner': 5},
#  93: {'awayScore': 197.0,
#       'awayTeamId': 2,
#       'homeScore': 234.5,
#       'homeTeamId': 4,
#       'week': 14,
#       'winner': 4},
#  94: {'awayScore': 185.5,
#       'awayTeamId': 12,
#       'homeScore': 187.0,
#       'homeTeamId': 8,
#       'week': 14,
#       'winner': 8},
#  95: {'awayScore': 184.0,
#       'awayTeamId': 1,
#       'homeScore': 170.5,
#       'homeTeamId': 6,
#       'week': 14,
#       'winner': 1},
#  96: {'awayScore': 160.0,
#       'awayTeamId': 7,
#       'homeScore': 198.5,
#       'homeTeamId': 9,
#       'week': 14,
#       'winner': 9}}
# --Matchup Rosters--
# {1: {'awayLineup': ['BE',
#                     'RB',
#                     'RB/WR',
#                     'RB/WR',
#                     'WR',
#                     'TE',
#                     'BE',
#                     'QB',
#                     'BE',
#                     'BE',
#                     'BE',
#                     'D/ST',
#                     'BE',
#                     'K'],
#      'awayRoster': ['Mike Evans',
#                     'Clyde Edwards-Helaire',
#                     'Tyler Lockett',
#                     'James Conner',
#                     'A.J. Green',
#                     'Darren Waller',
#                     'James White',
#                     'Tom Brady',
#                     'Golden Tate',
#                     'Darrell Henderson Jr.',
#                     'DeSean Jackson',
#                     'Vikings D/ST',
#                     'Eric Ebron',
#                     'Robbie Gould'],
#      'awayRosterEligibleSlots': [['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['Rookie',
#                                   'RB',
#                                   'RB/WR',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['QB', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['D/ST', 'BE', 'IR'],
#                                  ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['K', 'BE', 'IR']],
#      'awayRosterScore': [6.5,
#                          19.0,
#                          13.0,
#                          1.0,
#                          7.5,
#                          7.0,
#                          6.5,
#                          19.0,
#                          0.0,
#                          0.0,
#                          5.0,
#                          -9.0,
#                          1.5,
#                          10.0],
#      'awayScore': 67.5,
#      'awayTeamId': 9,
#      'homeLineup': ['WR',
#                     'QB',
#                     'BE',
#                     'RB',
#                     'RB/WR',
#                     'RB/WR',
#                     'TE',
#                     'BE',
#                     'BE',
#                     'BE',
#                     'BE',
#                     'BE',
#                     'K',
#                     'D/ST'],
#      'homeRoster': ['Michael Thomas',
#                     'Patrick Mahomes',
#                     'Courtland Sutton',
#                     'Devin Singletary',
#                     'Michael Gallup',
#                     'Ronald Jones II',
#                     'Noah Fant',
#                     'Kerryon Johnson',
#                     'Emmanuel Sanders',
#                     'Mecole Hardman',
#                     'Bears D/ST',
#                     'Chris Thompson',
#                     'Chris Boswell',
#                     'Eagles D/ST'],
#      'homeRosterEligibleSlots': [['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['QB', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['D/ST', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['K', 'BE', 'IR'],
#                                  ['D/ST', 'BE', 'IR']],
#      'homeRosterScore': [2.5,
#                          20.0,
#                          0.0,
#                          7.5,
#                          6.5,
#                          8.0,
#                          16.5,
#                          1.0,
#                          8.5,
#                          0.5,
#                          0.0,
#                          1.0,
#                          9.0,
#                          5.0],
#      'homeScore': 75.0,
#      'homeTeamId': 12,
#      'week': 1,
#      'winner': 12},
#  2: {'awayLineup': ['BE',
#                     'RB',
#                     'WR',
#                     'RB/WR',
#                     'RB/WR',
#                     'TE',
#                     'BE',
#                     'QB',
#                     'BE',
#                     'BE',
#                     'D/ST',
#                     'BE',
#                     'BE',
#                     'K'],
#      'awayRoster': ['Miles Sanders',
#                     'Ezekiel Elliott',
#                     'Allen Robinson II',
#                     'David Johnson',
#                     'DK Metcalf',
#                     'Evan Engram',
#                     'Brandin Cooks',
#                     'Matt Ryan',
#                     'Jordan Howard',
#                     'John Brown',
#                     'Ravens D/ST',
#                     'Curtis Samuel',
#                     'Mike Williams',
#                     'Zane Gonzalez'],
#      'awayRosterEligibleSlots': [['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['QB', 'OP', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['D/ST', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['K', 'BE', 'IR']],
#      'awayRosterScore': [0.0,
#                          25.5,
#                          9.5,
#                          17.5,
#                          17.0,
#                          1.0,
#                          3.0,
#                          24.0,
#                          6.0,
#                          16.0,
#                          12.0,
#                          5.5,
#                          8.0,
#                          6.0],
#      'awayScore': 112.5,
#      'awayTeamId': 5,
#      'homeLineup': ['RB',
#                     'RB/WR',
#                     'WR',
#                     'BE',
#                     'TE',
#                     'RB/WR',
#                     'BE',
#                     'BE',
#                     'BE',
#                     'QB',
#                     'D/ST',
#                     'BE',
#                     'BE',
#                     'K'],
#      'homeRoster': ['Saquon Barkley',
#                     'Derrick Henry',
#                     'JuJu Smith-Schuster',
#                     'Kenny Golladay',
#                     'Mark Andrews',
#                     'Calvin Ridley',
#                     'Kareem Hunt',
#                     'Antonio Gibson',
#                     'Rob Gronkowski',
#                     'Drew Brees',
#                     'Patriots D/ST',
#                     'Tevin Coleman',
#                     'LeSean McCoy',
#                     'Matt Prater'],
#      'homeRosterEligibleSlots': [['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['QB', 'OP', 'BE', 'IR'],
#                                  ['D/ST', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['K', 'BE', 'IR']],
#      'homeRosterScore': [9.0,
#                          13.5,
#                          21.0,
#                          0.0,
#                          19.5,
#                          29.5,
#                          9.0,
#                          4.0,
#                          2.0,
#                          14.0,
#                          12.0,
#                          1.5,
#                          0.5,
#                          11.0],
#      'homeScore': 129.5,
#      'homeTeamId': 6,
#      'week': 1,
#      'winner': 6},
#  3: {'awayLineup': ['WR',
#                     'RB',
#                     'RB/WR',
#                     'RB/WR',
#                     'BE',
#                     'QB',
#                     'TE',
#                     'BE',
#                     'BE',
#                     'D/ST',
#                     'BE',
#                     'BE',
#                     'K',
#                     'BE'],
#      'awayRoster': ['Tyreek Hill',
#                     'Joe Mixon',
#                     'Aaron Jones',
#                     'Todd Gurley II',
#                     'Jarvis Landry',
#                     'Russell Wilson',
#                     'Jared Cook',
#                     'Henry Ruggs III',
#                     'Jamison Crowder',
#                     'Steelers D/ST',
#                     'Alexander Mattison',
#                     'Joe Burrow',
#                     'Younghoe Koo',
#                     'Darrynton Evans'],
#      'awayRosterEligibleSlots': [['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['QB', 'OP', 'BE', 'IR'],
#                                  ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['Rookie',
#                                   'RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['D/ST', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['Rookie', 'QB', 'OP', 'BE', 'IR'],
#                                  ['K', 'BE', 'IR'],
#                                  ['Rookie',
#                                   'RB',
#                                   'RB/WR',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR']],
#      'awayRosterScore': [12.5,
#                          4.5,
#                          15.0,
#                          12.0,
#                          8.5,
#                          30.0,
#                          10.5,
#                          7.5,
#                          20.5,
#                          10.0,
#                          10.0,
#                          15.0,
#                          9.0,
#                          0.0],
#      'awayScore': 103.5,
#      'awayTeamId': 10,
#      'homeLineup': ['QB',
#                     'RB',
#                     'RB/WR',
#                     'WR',
#                     'RB/WR',
#                     'BE',
#                     'BE',
#                     'BE',
#                     'TE',
#                     'K',
#                     'D/ST',
#                     'BE',
#                     'BE'],
#      'homeRoster': ['Dak Prescott',
#                     'Nick Chubb',
#                     'Kenyan Drake',
#                     'Robert Woods',
#                     'Stefon Diggs',
#                     'Mark Ingram II',
#                     'Sterling Shepard',
#                     'Preston Williams',
#                     'Austin Hooper',
#                     'Harrison Butker',
#                     'Broncos D/ST',
#                     "N'Keal Harry",
#                     'Sammy Watkins'],
#      'homeRosterEligibleSlots': [['QB', 'OP', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                  ['K', 'BE', 'IR'],
#                                  ['D/ST', 'BE', 'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR'],
#                                  ['RB/WR',
#                                   'WR',
#                                   'WR/TE',
#                                   'RB/WR/TE',
#                                   'OP',
#                                   'BE',
#                                   'IR']],
#      'homeRosterScore': [17.0,
#                          4.5,
#                          13.0,
#                          14.0,
#                          12.0,
#                          2.0,
#                          7.0,
#                          5.0,
#                          2.0,
#                          10.0,
#                          3.0,
#                          3.5,
#                          17.5],
#      'homeScore': 75.5,
#      'homeTeamId': 8,
#      'week': 1,
#      'winner': 10},
#  4: {'awayLineup': ['RB',
#                     'RB/WR',
#                     'TE',
#                     'WR',
#                     'RB/WR',
#                     'BE',
#                     'BE',
#                     'BE',
#                     'BE',
#                     'QB',
#                     'BE',
#                     'K',
#                     'BE',
#                     'D/ST'],
#      'awayRoster': ['Alvin Kamara',
#                     'Christian McCaffrey',
#                     'Travis Kelce',
#                     'Cooper Kupp',
#                     'Terry McLaurin',
#                     'Hunter Henry',
#                     'Tyler Boyd',
#                     'Christian Kirk',
#                     'Marlon Mack',
#                     'Aaron Rodgers',
#                     'Latavius Murray',
#                     'Jason Myers',
#                     'O.J. Howard',
#                     'Chargers D/ST'],
#      'awayRosterEligibleSlots': [['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
# ...
#                                   ['D/ST', 'BE', 'IR'],
#                                   ['RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['QB', 'OP', 'BE', 'IR'],
#                                   ['RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['K', 'BE', 'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR']],
#       'homeRosterScore': [0.0,
#                           11.0,
#                           6.0,
#                           36.5,
#                           0.0,
#                           10.5,
#                           2.0,
#                           0.0,
#                           8.0,
#                           15.0,
#                           5.5,
#                           20.0,
#                           1.0,
#                           0.0,
#                           10.0],
#       'homeScore': 187.0,
#       'homeTeamId': 8,
#       'week': 14,
#       'winner': 8},
#  95: {'awayLineup': ['BE',
#                      'BE',
#                      'BE',
#                      'D/ST',
#                      'IR',
#                      'RB',
#                      'WR',
#                      'BE',
#                      'BE',
#                      'RB/WR',
#                      'RB/WR',
#                      'IR',
#                      'TE',
#                      'K',
#                      'BE',
#                      'QB'],
#       'awayRoster': ['DJ Chark Jr.',
#                      'Melvin Gordon III',
#                      'Cam Newton',
#                      'Cardinals D/ST',
#                      'Myles Gaskin',
#                      'Mike Davis',
#                      'Justin Jefferson',
#                      'Hunter Henry',
#                      'Ezekiel Elliott',
#                      'Antonio Brown',
#                      'J.D. McKissic',
#                      'Devonta Freeman',
#                      'Logan Thomas',
#                      'Jason Myers',
#                      'DeAndre Washington',
#                      'Jared Goff'],
#       'awayRosterEligibleSlots': [['RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['QB', 'OP', 'BE', 'IR'],
#                                   ['D/ST', 'BE', 'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['Rookie',
#                                    'RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['K', 'BE', 'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['QB', 'OP', 'BE', 'IR']],
#       'awayRosterScore': [14.0,
#                           7.0,
#                           9.0,
#                           4.0,
#                           30.5,
#                           8.0,
#                           11.0,
#                           0.0,
#                           15.0,
#                           11.0,
#                           18.0,
#                           0.0,
#                           9.5,
#                           10.0,
#                           0.0,
#                           9.0],
#       'awayScore': 184.0,
#       'awayTeamId': 1,
#       'homeLineup': ['IR',
#                      'RB',
#                      'RB/WR',
#                      'BE',
#                      'BE',
#                      'WR',
#                      'RB/WR',
#                      'BE',
#                      'BE',
#                      'K',
#                      'BE',
#                      'QB',
#                      'TE',
#                      'BE',
#                      'D/ST'],
#       'homeRoster': ['Saquon Barkley',
#                      'Derrick Henry',
#                      'JuJu Smith-Schuster',
#                      'Kenny Golladay',
#                      'Mark Andrews',
#                      'Calvin Ridley',
#                      'Kareem Hunt',
#                      'Antonio Gibson',
#                      'Jerick McKinnon',
#                      'Jason Sanders',
#                      'Christian Kirk',
#                      'Kirk Cousins',
#                      'Robert Tonyan',
#                      'Chargers D/ST',
#                      'Vikings D/ST'],
#       'homeRosterEligibleSlots': [['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['K', 'BE', 'IR'],
#                                   ['RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['QB', 'OP', 'BE', 'IR'],
#                                   ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['D/ST', 'BE', 'IR'],
#                                   ['D/ST', 'BE', 'IR']],
#       'homeRosterScore': [0.0,
#                           9.0,
#                           19.5,
#                           0.0,
#                           10.0,
#                           15.5,
#                           12.5,
#                           7.5,
#                           3.5,
#                           15.0,
#                           10.5,
#                           23.0,
#                           1.5,
#                           6.0,
#                           -8.0],
#       'homeScore': 170.5,
#       'homeTeamId': 6,
#       'week': 14,
#       'winner': 1},
#  96: {'awayLineup': ['RB/WR',
#                      'RB',
#                      'K',
#                      'D/ST',
#                      'BE',
#                      'WR',
#                      'BE',
#                      'BE',
#                      'BE',
#                      'RB/WR',
#                      'BE',
#                      'QB',
#                      'BE',
#                      'TE'],
#       'awayRoster': ['Leonard Fournette',
#                      'Jonathan Taylor',
#                      'Rodrigo Blankenship',
#                      'Colts D/ST',
#                      'Tee Higgins',
#                      'CeeDee Lamb',
#                      'Wayne Gallman',
#                      'Seahawks D/ST',
#                      'Derek Carr',
#                      'Corey Davis',
#                      'Tua Tagovailoa',
#                      'Jalen Hurts',
#                      'Jared Cook',
#                      'Mike Gesicki'],
#       'awayRosterEligibleSlots': [['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['Rookie',
#                                    'RB',
#                                    'RB/WR',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['Rookie', 'K', 'BE', 'IR'],
#                                   ['D/ST', 'BE', 'IR'],
#                                   ['Rookie',
#                                    'RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['Rookie',
#                                    'RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['D/ST', 'BE', 'IR'],
#                                   ['QB', 'OP', 'BE', 'IR'],
#                                   ['RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['Rookie', 'QB', 'OP', 'BE', 'IR'],
#                                   ['Rookie', 'QB', 'OP', 'BE', 'IR'],
#                                   ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['WR/TE',
#                                    'TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR']],
#       'awayRosterScore': [13.5,
#                           19.0,
#                           6.0,
#                           -1.0,
#                           18.0,
#                           20.5,
#                           5.0,
#                           8.0,
#                           23.0,
#                           0.0,
#                           8.0,
#                           17.0,
#                           9.5,
#                           7.0],
#       'awayScore': 160.0,
#       'awayTeamId': 7,
#       'homeLineup': ['WR',
#                      'RB/WR',
#                      'BE',
#                      'BE',
#                      'IR',
#                      'K',
#                      'RB',
#                      'BE',
#                      'RB/WR',
#                      'QB',
#                      'BE',
#                      'D/ST',
#                      'TE',
#                      'BE',
#                      'BE'],
#       'homeRoster': ['Mike Evans',
#                      'James Conner',
#                      'James White',
#                      'Darrell Henderson Jr.',
#                      'DeSean Jackson',
#                      'Robbie Gould',
#                      'Austin Ekeler',
#                      'Tyler Higbee',
#                      "Le'Veon Bell",
#                      'Deshaun Watson',
#                      'Darius Slayton',
#                      'Browns D/ST',
#                      'Eric Ebron',
#                      'Michael Badgley',
#                      'Benny Snell Jr.'],
#       'homeRosterEligibleSlots': [['RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['K', 'BE', 'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['RB', 'RB/WR', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['QB', 'OP', 'BE', 'IR'],
#                                   ['RB/WR',
#                                    'WR',
#                                    'WR/TE',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR'],
#                                   ['D/ST', 'BE', 'IR'],
#                                   ['WR/TE', 'TE', 'RB/WR/TE', 'OP', 'BE', 'IR'],
#                                   ['K', 'BE', 'IR'],
#                                   ['RB',
#                                    'RB/WR',
#                                    'RB/WR/TE',
#                                    'OP',
#                                    'BE',
#                                    'IR']],
#       'homeRosterScore': [35.0,
#                           14.5,
#                           4.5,
#                           6.0,
#                           14.5,
#                           0.0,
#                           13.5,
#                           4.5,
#                           3.5,
#                           25.0,
#                           3.0,
#                           6.0,
#                           12.5,
#                           14.0,
#                           0.0],
#       'homeScore': 198.5,
#       'homeTeamId': 9,
#       'week': 14,
#       'winner': 9}}
