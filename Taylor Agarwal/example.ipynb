# %%
from ESPNAPI import League
import pprint

#year = "2021"
#leagueID = "2132617421"
#espn_s2 = "AEBlmW%2BnPlQPu68%2B3lzmpbsb5hNTRKEtHrL%2Bq8FkioyJ%2BAkHtJm7yYEagGmtwT%2BH4Wb9lhRdwJzDvYyDuUQ8huceOylAFUJtO3MVkxn0EsDJk47eyalQUduQyirWQiRoByYOp%2Bjhc8pG4Gfi2KftR2%2FBXgElrd734Lz0TBXCYDb33tB3PQt8S1Q6GcdZZ757%2BMeBz%2Fd87XfRCkn3Kgs%2FnB40EJtzL30SlEPeKBmB%2ByUdrysHbYZz9ESlKSIkBuey92sudtrZvPf5NUAIoAOmX2Py7fM1V1E%2F0zHImDLRUcar%2Bw%3D%3D"
#swid = "{9AED192A-A64B-4ECA-9772-BDDE2396067C}"

year = "2020"
leagueID = "139889"
espn_s2 = "AEBVAY4IP16BsQVvRgpY1hGOur4OKjZCVh6vfBIibHEoA5BHQCg3rZGBvbNbuESU3bQlfQzdveoAqNcmIhoBoO10gq2K%2FOhtdYamn6aQBihs%2FydsgoJehuJgLwAIdcaXlnehxcpTltR58fP0cX18vjZReJjo0OjZGUSOr3ff0Iuz1Ztt8c4rUkFJVTd8cEd%2BT76%2Bvva8s5iQGAfKTUfPA9P2k6xC33qYcaH%2FIYykwIC00PKoJOlysod9yM5bUrA39lpJ2WZQfdICgqXt5zu%2FYaDpiXVznvExI4BIoEFnEVfs3w%3D%3D"
swid = "{65C194B8-D67C-4A07-8990-988E5F391434}"

My_League = League(year, leagueID, espn_s2, swid)

reader = pprint.PrettyPrinter()
#pd.DataFrame.from_dict(IAA_League.fetch_teams(), orient = 'index')
print("--Teams--")
reader.pprint(My_League.fetch_teams())
print("--Rosters--")
reader.pprint(My_League.fetch_rosters())
print("--Matchups--")
reader.pprint(My_League.fetch_matchups())
print("--Matchup Rosters--")
reader.pprint(My_League.fetch_matchup_rosters())
# Out:
# {1: {'awayLineup': [20, 2, 3, 3, 4, 6, 20, 0, 20, 20, 20, 16, 20, 17],
#      'awayRoster': ['Mike Evans',
#                     'Clyde Edwards-Helaire',
#                     'Tyler Lockett',
#                     'James Conner',
#                     'A.J. Green',
#                     'Darren Waller',
#                     'James White',
#                     'Tom Brady',
#                     'Golden Tate',
#                     'Darrell Henderson Jr.',
#                     'DeSean Jackson',
#                     'Vikings D/ST',
#                     'Eric Ebron',
#                     'Robbie Gould'],
#      'awayRosterScore': [6.5,
#                          19.0,
#                          13.0,
#                          1.0,
#                          7.5,
#                          7.0,
#                          6.5,
#                          19.0,
#                          0.0,
#                          0.0,
#                          5.0,
#                          -9.0,
#                          1.5,
#                          10.0],
#      'awayScore': 67.5,
#      'awayTeamId': 9,
#      'homeLineup': [4, 0, 20, 2, 3, 3, 6, 20, 20, 20, 20, 20, 17, 16],
#      'homeRoster': ['Michael Thomas',
#                     'Patrick Mahomes',
#                     'Courtland Sutton',
#                     'Devin Singletary',
#                     'Michael Gallup',
#                     'Ronald Jones II',
#                     'Noah Fant',
#                     'Kerryon Johnson',
#                     'Emmanuel Sanders',
#                     'Mecole Hardman',
#                     'Bears D/ST',
#                     'Chris Thompson',
#                     'Chris Boswell',
#                     'Eagles D/ST'],
#      'homeRosterScore': [2.5,
#                          20.0,
#                          0.0,
#                          7.5,
#                          6.5,
#                          8.0,
#                          16.5,
#                          1.0,
#                          8.5,
#                          0.5,
#                          0.0,
#                          1.0,
#                          9.0,
#                          5.0],
#      'homeScore': 75.0,
#      'homeTeamId': 12,
#      'week': 1,
#      'winner': 12},
#  2: {'awayLineup': [20, 2, 4, 3, 3, 6, 20, 0, 20, 20, 16, 20, 20, 17],
#      'awayRoster': ['Miles Sanders',
#                     'Ezekiel Elliott',
#                     'Allen Robinson II',
#                     'David Johnson',
#                     'DK Metcalf',
#                     'Evan Engram',
#                     'Brandin Cooks',
#                     'Matt Ryan',
#                     'Jordan Howard',
#                     'John Brown',
#                     'Ravens D/ST',
#                     'Curtis Samuel',
#                     'Mike Williams',
#                     'Zane Gonzalez'],
#      'awayRosterScore': [0.0,
#                          25.5,
#                          9.5,
#                          17.5,
#                          17.0,
#                          1.0,
#                          3.0,
#                          24.0,
#                          6.0,
#                          16.0,
#                          12.0,
#                          5.5,
#                          8.0,
#                          6.0],
#      'awayScore': 112.5,
#      'awayTeamId': 5,
#      'homeLineup': [2, 3, 4, 20, 6, 3, 20, 20, 20, 0, 16, 20, 20, 17],
#      'homeRoster': ['Saquon Barkley',
#                     'Derrick Henry',
#                     'JuJu Smith-Schuster',
#                     'Kenny Golladay',
#                     'Mark Andrews',
#                     'Calvin Ridley',
#                     'Kareem Hunt',
#                     'Antonio Gibson',
#                     'Rob Gronkowski',
#                     'Drew Brees',
#                     'Patriots D/ST',
#                     'Tevin Coleman',
#                     'LeSean McCoy',
#                     'Matt Prater'],
#      'homeRosterScore': [9.0,
#                          13.5,
#                          21.0,
#                          0.0,
#                          19.5,
#                          29.5,
#                          9.0,
#                          4.0,
#                          2.0,
#                          14.0,
#                          12.0,
#                          1.5,
#                          0.5,
#                          11.0],
#      'homeScore': 129.5,
#      'homeTeamId': 6,
#      'week': 1,
#      'winner': 6},
#  3: {'awayLineup': [4, 2, 3, 3, 20, 0, 6, 20, 20, 16, 20, 20, 17, 20],
#      'awayRoster': ['Tyreek Hill',
#                     'Joe Mixon',
#                     'Aaron Jones',
#                     'Todd Gurley II',
#                     'Jarvis Landry',
#                     'Russell Wilson',
#                     'Jared Cook',
#                     'Henry Ruggs III',
#                     'Jamison Crowder',
#                     'Steelers D/ST',
#                     'Alexander Mattison',
#                     'Joe Burrow',
#                     'Younghoe Koo',
#                     'Darrynton Evans'],
#      'awayRosterScore': [12.5,
#                          4.5,
#                          15.0,
#                          12.0,
#                          8.5,
#                          30.0,
#                          10.5,
#                          7.5,
#                          20.5,
#                          10.0,
#                          10.0,
#                          15.0,
#                          9.0,
#                          0.0],
#      'awayScore': 103.5,
#      'awayTeamId': 10,
#      'homeLineup': [0, 2, 3, 4, 3, 20, 20, 20, 6, 17, 16, 20, 20],
#      'homeRoster': ['Dak Prescott',
#                     'Nick Chubb',
#                     'Kenyan Drake',
#                     'Robert Woods',
#                     'Stefon Diggs',
#                     'Mark Ingram II',
#                     'Sterling Shepard',
#                     'Preston Williams',
#                     'Austin Hooper',
#                     'Harrison Butker',
#                     'Broncos D/ST',
#                     "N'Keal Harry",
#                     'Sammy Watkins'],
#      'homeRosterScore': [17.0,
#                          4.5,
#                          13.0,
#                          14.0,
#                          12.0,
#                          2.0,
#                          7.0,
#                          5.0,
#                          2.0,
#                          10.0,
#                          3.0,
#                          3.5,
#                          17.5],
#      'homeScore': 75.5,
#      'homeTeamId': 8,
#      'week': 1,
#      'winner': 10},
#  4: {'awayLineup': [2, 3, 6, 4, 3, 20, 20, 20, 20, 0, 20, 17, 20, 16],
#      'awayRoster': ['Alvin Kamara',
#                     'Christian McCaffrey',
#                     'Travis Kelce',
#                     'Cooper Kupp',
#                     'Terry McLaurin',
#                     'Hunter Henry',
#                     'Tyler Boyd',
#                     'Christian Kirk',
#                     'Marlon Mack',
#                     'Aaron Rodgers',
#                     'Latavius Murray',
#                     'Jason Myers',
#                     'O.J. Howard',
#                     'Chargers D/ST'],
#      'awayRosterScore': [20.5,
#                          25.5,
#                          14.0,
#                          6.0,
#                          8.5,
#                          9.5,
#                          5.0,
#                          0.5,
#                          6.5,
#                          30.0,
#                          4.0,
#                          9.0,
#                          11.0,
#                          12.0],
#      'awayScore': 125.5,
#      'awayTeamId': 4,
#      'homeLineup': [4, 3, 6, 20, 3, 20, 20, 20, 21, 2, 17, 20, 20, 0, 16],
#      'homeRoster': ['DeAndre Hopkins',
#                     'DJ Chark Jr.',
#                     'George Kittle',
#                     'Melvin Gordon III',
#                     'Julian Edelman',
#                     'CeeDee Lamb',
#                     'Matt Breida',
#                     'Chase Edmonds',
#                     'Damien Harris',
#                     'Boston Scott',
#                     'Greg Zuerlein',
#                     'Jordan Love',
#                     'Jerry Jeudy',
#                     'Cam Newton',
#                     'Lions D/ST'],
#      'homeRosterScore': [22.0,
#                          9.5,
#                          6.0,
#                          12.5,
#                          9.5,
#                          7.5,
#                          2.0,
#                          10.5,
#                          0.0,
#                          5.0,
#                          4.0,
#                          0.0,
#                          7.0,
#                          25.0,
#                          0.0],
#      'homeScore': 81.0,
#      'homeTeamId': 1,
#      'week': 1,
#      'winner': 4},
#  5: {'awayLineup': [4, 2, 3, 3, 20, 20, 20, 6, 16, 20, 0, 17, 20, 20],
#      'awayRoster': ['Chris Godwin',
#                     'Leonard Fournette',
#                     'Odell Beckham Jr.',
#                     'Jonathan Taylor',
#                     'Marquise Brown',
#                     'Will Fuller V',
#                     'Deebo Samuel',
#                     'T.J. Hockenson',
#                     'Bills D/ST',
#                     'Sony Michel',
#                     'Carson Wentz',
#                     'Rodrigo Blankenship',
#                     'Dallas Goedert',
#                     'Bryan Edwards'],
#      'awayRosterScore': [10.0,
#                          1.5,
#                          3.5,
#                          11.0,
#                          12.5,
#                          15.0,
#                          0.0,
#                          13.5,
#                          10.0,
#                          9.0,
#                          12.0,
#                          7.0,
#                          20.0,
#                          0.5],
#      'awayScore': 68.5,
#      'awayTeamId': 7,
#      'homeLineup': [3, 4, 2, 20, 0, 3, 20, 20, 20, 6, 16, 20, 20, 17],
#      'homeRoster': ['Chris Carson',
#                     'Julio Jones',
#                     'Josh Jacobs',
#                     'Amari Cooper',
#                     'Deshaun Watson',
#                     'A.J. Brown',
#                     "D'Andre Swift",
#                     'David Montgomery',
#                     'Diontae Johnson',
#                     'Hayden Hurst',
#                     '49ers D/ST',
#                     'Darius Slayton',
#                     'Mike Gesicki',
#                     'Wil Lutz'],
#      'homeRosterScore': [21.0,
#                          19.5,
#                          33.0,
#                          13.0,
#                          20.0,
#                          5.5,
#                          8.5,
#                          7.5,
#                          6.0,
#                          4.5,
#                          1.0,
#                          25.0,
#                          4.5,
#                          10.0],
#      'homeScore': 114.5,
#      'homeTeamId': 11,
#      'week': 1,
#      'winner': 11},
#  6: {'awayLineup': [2, 3, 4, 3, 20, 20, 20, 0, 6, 20, 17, 16, 20, 20],
#      'awayRoster': ['Austin Ekeler',
#                     'Dalvin Cook',
#                     'Adam Thielen',
#                     'DJ Moore',
#                     "Le'Veon Bell",
#                     'T.Y. Hilton',
#                     'Cam Akers',
#                     'Kyler Murray',
#                     'Tyler Higbee',
#                     'Zack Moss',
#                     'Justin Tucker',
#                     'Colts D/ST',
#                     'J.K. Dobbins',
#                     'Jonnu Smith'],
#      'awayRosterScore': [8.5,
#                          21.5,
#                          28.0,
#                          7.0,
#                          5.0,
#                          7.0,
#                          3.5,
#                          26.0,
#                          5.5,
#                          9.5,
#                          9.0,
#                          6.0,
#                          14.0,
#                          11.0],
#      'awayScore': 111.5,
#      'awayTeamId': 3,
#      'homeLineup': [0, 6, 4, 3, 2, 3, 20, 20, 20, 20, 20, 20, 16, 17],
#      'homeRoster': ['Lamar Jackson',
#                     'Zach Ertz',
#                     'Davante Adams',
#                     'Keenan Allen',
#                     'Raheem Mostert',
#                     'Marvin Jones Jr.',
#                     'Phillip Lindsay',
#                     'DeVante Parker',
#                     'Tarik Cohen',
#                     'Matthew Stafford',
#                     'Robby Anderson',
#                     'Duke Johnson',
#                     'Cowboys D/ST',
#                     'Austin Seibert'],
#      'homeRosterScore': [27.0,
#                          8.5,
#                          34.0,
#                          5.0,
#                          22.0,
#                          7.0,
#                          3.5,
#                          6.0,
#                          5.0,
#                          15.0,
#                          22.0,
#                          1.0,
#                          0.0,
#                          -1.0],
#      'homeScore': 102.5,
#      'homeTeamId': 2,
#      'week': 1,
#      'winner': 3},
#  7: {'awayLineup': [3, 2, 4, 3, 20, 6, 20, 0, 20, 20, 16, 20, 20, 17],
#      'awayRoster': ['Miles Sanders',
#                     'Ezekiel Elliott',
#                     'Allen Robinson II',
#                     'David Johnson',
#                     'DK Metcalf',
#                     'Evan Engram',
#                     'Brandin Cooks',
#                     'Matt Ryan',
#                     'Jordan Howard',
#                     'John Brown',
#                     'Ravens D/ST',
#                     'Curtis Samuel',
#                     'Mike Williams',
#                     'Zane Gonzalez'],
#      'awayRosterScore': [17.5,
#                          18.0,
#                          4.5,
#                          5.0,
#                          17.0,
#                          9.0,
#                          11.5,
#                          27.0,
#                          6.0,
#                          16.0,
#                          15.0,
#                          4.0,
#                          2.0,
#                          13.0],
#      'awayScore': 109.0,
#      'awayTeamId': 5,
#      'homeLineup': [3, 2, 3, 20, 4, 6, 20, 0, 20, 20, 20, 16, 20, 17],
#      'homeRoster': ['Mike Evans',
#                     'Clyde Edwards-Helaire',
#                     'Tyler Lockett',
#                     'James Conner',
#                     'A.J. Green',
#                     'Darren Waller',
#                     'James White',
#                     'Tom Brady',
#                     'Golden Tate',
#                     'Darrell Henderson Jr.',
#                     'DeSean Jackson',
#                     'Vikings D/ST',
#                     'Eric Ebron',
#                     'Robbie Gould'],
#      'homeRosterScore': [19.5,
#                          9.0,
#                          15.5,
#                          18.0,
#                          3.5,
#                          22.0,
#                          0.0,
#                          8.0,
#                          6.5,
#                          19.0,
#                          9.0,
#                          3.0,
#                          5.5,
#                          8.0],
#      'homeScore': 88.5,
#      'homeTeamId': 9,
#      'week': 2,
#      'winner': 5},
#  8: {'awayLineup': [21, 0, 20, 2, 3, 3, 6, 4, 20, 17, 20, 20, 20, 16],
#      'awayRoster': ['Michael Thomas',
#                     'Patrick Mahomes',
#                     'Courtland Sutton',
#                     'Devin Singletary',
#                     'Michael Gallup',
#                     'Ronald Jones II',
#                     'Noah Fant',
#                     'Emmanuel Sanders',
#                     'Mecole Hardman',
#                     'Chris Boswell',
#                     'Eagles D/ST',
#                     'Nyheim Hines',
#                     'Benny Snell Jr.',
#                     'Saints D/ST'],
#      'awayRosterScore': [0.0,
#                          27.0,
#                          7.5,
#                          8.0,
#                          6.0,
#                          9.0,
#                          15.0,
#                          1.5,
#                          6.0,
#                          6.0,
#                          -1.0,
#                          0.5,
#                          -1.5,
#                          3.0],
#      'awayScore': 75.5,
#      'awayTeamId': 12,
#      'homeLineup': [4, 2, 3, 3, 20, 0, 6, 20, 20, 16, 20, 20, 17, 20],
#      'homeRoster': ['Tyreek Hill',
#                     'Joe Mixon',
#                     'Aaron Jones',
#                     'Todd Gurley II',
#                     'Jarvis Landry',
#                     'Russell Wilson',
#                     'Jared Cook',
#                     'Henry Ruggs III',
#                     'Jamison Crowder',
#                     'Steelers D/ST',
#                     'Alexander Mattison',
#                     'Joe Burrow',
#                     'Younghoe Koo',
#                     'Darrynton Evans'],
#      'homeRosterScore': [17.5,
#                          10.0,
#                          42.0,
#                          6.0,
#                          5.5,
#                          32.0,
#                          8.0,
#                          0.5,
#                          0.0,
#                          13.0,
#                          1.5,
#                          23.0,
#                          17.0,
#                          0.0],
#      'homeScore': 145.5,
#      'homeTeamId': 10,
#      'week': 2,
#      'winner': 10},
#  9: {'awayLineup': [2, 3, 4, 20, 6, 3, 20, 20, 20, 0, 16, 20, 17, 20],
#      'awayRoster': ['Saquon Barkley',
#                     'Derrick Henry',
#                     'JuJu Smith-Schuster',
#                     'Kenny Golladay',
#                     'Mark Andrews',
#                     'Calvin Ridley',
#                     'Kareem Hunt',
#                     'Antonio Gibson',
#                     'Rob Gronkowski',
#                     'Drew Brees',
#                     'Patriots D/ST',
#                     'Tevin Coleman',
#                     'Matt Prater',
#                     'Allen Lazard'],
#      'awayRosterScore': [2.0,
#                          8.0,
#                          7.5,
#                          0.0,
#                          2.5,
#                          25.5,
#                          22.0,
#                          11.5,
#                          0.0,
#                          14.0,
#                          4.0,
#                          4.0,
#                          2.0,
#                          5.5],
#      'awayScore': 65.5,
#      'awayTeamId': 6,
#      'homeLineup': [2, 3, 6, 4, 3, 20, 20, 20, 0, 20, 20, 20, 16, 17],
#      'homeRoster': ['Alvin Kamara',
#                     'Christian McCaffrey',
#                     'Travis Kelce',
#                     'Cooper Kupp',
#                     'Terry McLaurin',
#                     'Hunter Henry',
#                     'Tyler Boyd',
#                     'Christian Kirk',
#                     'Aaron Rodgers',
#                     'Latavius Murray',
#                     'O.J. Howard',
#                     'Parris Campbell',
#                     'Titans D/ST',
#                     'Joey Slye'],
#      'homeRosterScore': [32.5,
#                          21.0,
#                          19.5,
#                          9.5,
#                          21.5,
#                          11.0,
#                          16.5,
#                          6.0,
#                          18.5,
#                          3.0,
#                          1.5,
#                          0.0,
#                          0.0,
#                          5.0],
#      'homeScore': 127.5,
#      'homeTeamId': 4,
#      'week': 2,
#      'winner': 4},
#  10: {'awayLineup': [0, 2, 3, 20, 3, 20, 20, 20, 6, 17, 16, 20, 4],
#       'awayRoster': ['Dak Prescott',
#                      'Nick Chubb',
#                      'Kenyan Drake',
#                      'Robert Woods',
#                      'Stefon Diggs',
#                      'Mark Ingram II',
#                      'Sterling Shepard',
#                      'Preston Williams',
#                      'Austin Hooper',
#                      'Harrison Butker',
#                      'Broncos D/ST',
#                      "N'Keal Harry",
#                      'Sammy Watkins'],
#       'awayRosterScore': [39.0,
#                           24.5,
#                           9.0,
#                           9.0,
#                           25.0,
#                           14.0,
#                           3.0,
#                           4.5,
#                           3.0,
#                           13.0,
#                           2.0,
#                           11.0,
#                           1.5],
#       'awayScore': 117.0,
#       'awayTeamId': 8,
#       'homeLineup': [20, 20, 3, 2, 3, 4, 20, 20, 16, 20, 0, 17, 6, 20],
#       'homeRoster': ['Chris Godwin',
#                      'Leonard Fournette',
#                      'Odell Beckham Jr.',
#                      'Jonathan Taylor',
#                      'Marquise Brown',
#                      'Will Fuller V',
#                      'Deebo Samuel',
#                      'T.J. Hockenson',
#                      'Bills D/ST',
#                      'Sony Michel',
#                      'Carson Wentz',
#                      'Rodrigo Blankenship',
#                      'Dallas Goedert',
#                      'Bryan Edwards'],
#       'homeRosterScore': [0.0,
#                           25.0,
#                           15.0,
#                           17.0,
#                           6.5,
#                           0.0,
#                           0.0,
#                           8.0,
#                           -1.0,
#                           1.0,
#                           11.0,
#                           15.0,
#                           5.0,
#                           5.0],
#       'homeScore': 68.5,
#       'homeTeamId': 7,
#       'week': 2,
#       'winner': 8},
#  11: {'awayLineup': [4, 3, 21, 2, 20, 20, 20, 21, 20, 17, 20, 0, 3, 20, 16, 6],
#       'awayRoster': ['DeAndre Hopkins',
#                      'DJ Chark Jr.',
#                      'George Kittle',
#                      'Melvin Gordon III',
#                      'Julian Edelman',
#                      'CeeDee Lamb',
#                      'Chase Edmonds',
#                      'Damien Harris',
#                      'Boston Scott',
#                      'Greg Zuerlein',
#                      'Jerry Jeudy',
#                      'Cam Newton',
#                      'Malcolm Brown',
#                      'James Robinson',
#                      'Cardinals D/ST',
#                      'Jimmy Graham'],
#       'awayRosterScore': [16.0,
#                           10.0,
#                           0.0,
#                           15.0,
#                           21.0,
#                           13.0,
#                           1.5,
#                           0.0,
#                           4.5,
#                           11.0,
#                           8.0,
#                           33.0,
#                           4.0,
#                           18.5,
#                           9.0,
#                           1.5],
#       'awayScore': 99.5,
#       'awayTeamId': 1,
#       'homeLineup': [2, 3, 4, 3, 21, 20, 20, 0, 6, 20, 17, 20, 20, 20, 16],
#       'homeRoster': ['Austin Ekeler',
#                      'Dalvin Cook',
#                      'Adam Thielen',
#                      'DJ Moore',
#                      "Le'Veon Bell",
#                      'T.Y. Hilton',
#                      'Cam Akers',
#                      'Kyler Murray',
#                      'Tyler Higbee',
#                      'Zack Moss',
#                      'Justin Tucker',
#                      'J.K. Dobbins',
#                      'Jonnu Smith',
#                      'Joshua Kelley',
#                      'Bears D/ST'],
#       'homeRosterScore': [16.0,
#                           15.0,
#                           4.5,
#                           16.0,
#                           0.0,
#                           3.5,
#                           1.0,
#                           31.0,
#                           25.5,
#                           3.0,
#                           16.0,
#                           5.5,
#                           22.0,
#                           11.0,
#                           13.0],
#       'homeScore': 137.0,
#       'homeTeamId': 3,
#       'week': 2,
#       'winner': 3},
#  12: {'awayLineup': [3, 4, 2, 3, 0, 20, 20, 20, 20, 6, 16, 20, 17, 20],
#       'awayRoster': ['Chris Carson',
#                      'Julio Jones',
#                      'Josh Jacobs',
#                      'Amari Cooper',
#                      'Deshaun Watson',
#                      'A.J. Brown',
#                      "D'Andre Swift",
#                      'David Montgomery',
#                      'Diontae Johnson',
#                      'Hayden Hurst',
#                      '49ers D/ST',
#                      'Darius Slayton',
#                      'Wil Lutz',
#                      'Chris Herndon'],
#       'awayRosterScore': [17.5,
#                           3.0,
#                           10.5,
#                           13.0,
#                           14.0,
#                           0.0,
#                           9.5,
#                           19.5,
#                           19.0,
#                           15.5,
#                           6.0,
#                           4.5,
#                           6.0,
#                           0.5],
#       'awayScore': 85.5,
#       'awayTeamId': 11,
#       'homeLineup': [0, 6, 4, 3, 2, 3, 20, 20, 20, 20, 16, 20, 20, 17],
#       'homeRoster': ['Lamar Jackson',
#                      'Zach Ertz',
#                      'Davante Adams',
#                      'Keenan Allen',
#                      'Raheem Mostert',
#                      'Marvin Jones Jr.',
#                      'Phillip Lindsay',
#                      'DeVante Parker',
#                      'Tarik Cohen',
#                      'Robby Anderson',
#                      'Cowboys D/ST',
#                      'Josh Allen',
#                      'Peyton Barber',
#                      'Dan Bailey'],
#       'homeRosterScore': [17.0,
#                           6.5,
#                           4.5,
#                           12.5,
#                           17.0,
#                           10.0,
#                           0.0,
#                           13.5,
#                           2.5,
#                           12.5,
#                           -3.0,
#                           33.0,
#                           0.0,
#                           3.0],
#       'homeScore': 67.5,
#       'homeTeamId': 2,
#       'week': 2,
#       'winner': 11},
#  13: {'awayLineup': [4, 3, 20, 20, 20, 3, 20, 17, 2, 6, 21, 0, 20, 16, 20],
#       'awayRoster': ['Mike Evans',
#                      'James Conner',
#                      'A.J. Green',
#                      'James White',
#                      'Golden Tate',
#                      'Darrell Henderson Jr.',
#                      'DeSean Jackson',
#                      'Robbie Gould',
#                      'Austin Ekeler',
#                      'Tyler Higbee',
#                      "Le'Veon Bell",
#                      'Deshaun Watson',
#                      'Darius Slayton',
#                      'Browns D/ST',
#                      'Eric Ebron'],
#       'awayRosterScore': [13.0,
#                           22.0,
#                           5.5,
#                           0.0,
#                           5.5,
#                           17.5,
#                           2.0,
#                           13.0,
#                           24.5,
#                           7.0,
#                           0.0,
#                           16.0,
#                           4.5,
#                           13.0,
#                           13.5],
#       'awayScore': 126.0,
#       'awayTeamId': 9,
#       'homeLineup': [4, 2, 3, 3, 20, 0, 6, 20, 20, 16, 20, 17, 20, 20],
#       'homeRoster': ['Tyreek Hill',
#                      'Joe Mixon',
#                      'Aaron Jones',
#                      'Todd Gurley II',
#                      'Jarvis Landry',
#                      'Russell Wilson',
#                      'Jared Cook',
#                      'Henry Ruggs III',
#                      'Jamison Crowder',
#                      'Steelers D/ST',
#                      'Alexander Mattison',
#                      'Younghoe Koo',
#                      'Russell Gage',
#                      'Will Fuller V'],
#       'homeRosterScore': [17.5,
#                           6.0,
#                           14.0,
#                           14.5,
#                           5.0,
#                           36.0,
#                           3.0,
#                           0.0,
#                           0.0,
#                           9.0,
#                           2.0,
#                           7.0,
#                           3.0,
#                           13.0],
#       'homeScore': 107.0,
#       'homeTeamId': 10,
#       'week': 3,
#       'winner': 9},
#  14: {'awayLineup': [2, 21, 6, 4, 3, 20, 3, 20, 0, 17, 20, 20, 16, 20, 20],
#       'awayRoster': ['Alvin Kamara',
#                      'Christian McCaffrey',
#                      'Travis Kelce',
#                      'Cooper Kupp',
#                      'Terry McLaurin',
#                      'Hunter Henry',
#                      'Tyler Boyd',
#                      'Christian Kirk',
#                      'Aaron Rodgers',
#                      'Joey Slye',
#                      'Mike Gesicki',
#                      'Jamaal Williams',
#                      'Chargers D/ST',
#                      'Jared Goff',
#                      'Zack Moss'],
#       'awayRosterScore': [36.5,
#                           0.0,
#                           11.0,
#                           20.5,
#                           10.0,
#                           7.5,
#                           17.0,
#                           0.0,
#                           24.0,
#                           15.0,
#                           7.5,
#                           1.5,
#                           4.0,
#                           26.0,
#                           0.0],
#       'awayScore': 138.0,
#       'awayTeamId': 4,
#       'homeLineup': [3, 2, 4, 20, 3, 6, 20, 0, 20, 20, 16, 20, 20, 17],
#       'homeRoster': ['Miles Sanders',
#                      'Ezekiel Elliott',
#                      'Allen Robinson II',
#                      'David Johnson',
#                      'DK Metcalf',
#                      'Evan Engram',
#                      'Brandin Cooks',
#                      'Matt Ryan',
#                      'Jordan Howard',
#                      'John Brown',
#                      'Ravens D/ST',
#                      'Curtis Samuel',
#                      'Mike Williams',
#                      'Zane Gonzalez'],
#       'homeRosterScore': [12.0,
#                           14.0,
#                           23.0,
#                           11.0,
#                           17.0,
#                           3.5,
#                           3.5,
#                           11.0,
#                           6.0,
#                           0.0,
#                           1.0,
#                           6.0,
#                           1.5,
#                           7.0],
#       'homeScore': 88.5,
#       'homeTeamId': 5,
#       'week': 3,
#       'winner': 4},
#  15: {'awayLineup': [3, 3, 4, 2, 20, 20, 20, 20, 20, 17, 6, 16, 0, 20],
#       'awayRoster': ['Chris Godwin',
#                      'Leonard Fournette',
#                      'Odell Beckham Jr.',
#                      'Jonathan Taylor',
#                      'Marquise Brown',
#                      'Deebo Samuel',
#                      'T.J. Hockenson',
#                      'Bills D/ST',
#                      'Sony Michel',
#                      'Rodrigo Blankenship',
#                      'Dallas Goedert',
#                      'Colts D/ST',
#                      'Gardner Minshew II',
#                      'Joe Burrow'],
#       'awayRosterScore': [14.5,
#                           2.0,
#                           7.0,
#                           11.5,
#                           2.0,
#                           0.0,
#                           7.0,
#                           0.0,
#                           14.0,
#                           11.0,
#                           0.5,
#                           27.0,
#                           9.0,
#                           20.0],
#       'awayScore': 82.5,
#       'awayTeamId': 7,
#       'homeLineup': [20, 0, 21, 2, 3, 20, 6, 17, 20, 20, 4, 20, 3, 20, 16],
#       'homeRoster': ['Michael Thomas',
#                      'Patrick Mahomes',
#                      'Courtland Sutton',
#                      'Devin Singletary',
#                      'Michael Gallup',
#                      'Ronald Jones II',
#                      'Noah Fant',
#                      'Chris Boswell',
#                      'Nyheim Hines',
#                      'Devonta Freeman',
#                      'Corey Davis',
#                      'Ryan Tannehill',
#                      "Tre'Quan Smith",
#                      'Larry Fitzgerald',
#                      'Titans D/ST'],
#       'homeRosterScore': [0.0,
#                           39.0,
#                           0.0,
#                           14.0,
#                           22.0,
#                           8.0,
#                           6.5,
#                           8.0,
#                           8.0,
#                           1.0,
#                           8.5,
#                           10.5,
#                           6.0,
#                           0.5,
#                           2.0],
#       'homeScore': 106.0,
#       'homeTeamId': 12,
#       'week': 3,
#       'winner': 12},
#  16: {'awayLineup': [2, 4, 20, 20, 20, 0, 17, 20, 6, 20, 20, 16, 3, 3],
#       'awayRoster': ['Dalvin Cook',
#                      'Adam Thielen',
#                      'DJ Moore',
#                      'T.Y. Hilton',
#                      'Cam Akers',
#                      'Kyler Murray',
#                      'Justin Tucker',
#                      'J.K. Dobbins',
#                      'Jonnu Smith',
#                      'Joshua Kelley',
#                      'Mike Davis',
#                      'Buccaneers D/ST',
#                      'Clyde Edwards-Helaire',
#                      'Tyler Lockett'],
#       'awayRosterScore': [24.0,
#                           9.5,
#                           7.0,
#                           6.5,
#                           0.0,
#                           20.0,
#                           9.0,
#                           5.0,
#                           8.5,
#                           3.0,
#                           18.0,
#                           19.0,
#                           15.5,
#                           32.5],
#       'awayScore': 138.0,
#       'awayTeamId': 3,
#       'homeLineup': [21, 2, 3, 20, 6, 4, 20, 20, 20, 20, 16, 17, 20, 3, 0],
#       'homeRoster': ['Saquon Barkley',
#                      'Derrick Henry',
#                      'JuJu Smith-Schuster',
#                      'Kenny Golladay',
#                      'Mark Andrews',
#                      'Calvin Ridley',
#                      'Kareem Hunt',
#                      'Antonio Gibson',
#                      'Rob Gronkowski',
#                      'Drew Brees',
#                      'Patriots D/ST',
#                      'Matt Prater',
#                      'Allen Lazard',
#                      'Jerick McKinnon',
#                      'Ben Roethlisberger'],
#       'homeRosterScore': [0.0,
#                           25.0,
#                           14.0,
#                           14.0,
#                           3.5,
#                           13.5,
#                           12.0,
#                           10.5,
#                           7.0,
#                           23.0,
#                           13.0,
#                           14.0,
#                           23.0,
#                           13.5,
#                           19.0],
#       'homeScore': 115.5,
#       'homeTeamId': 6,
#       'week': 3,
#       'winner': 3},
#  17: {'awayLineup': [0, 6, 20, 3, 20, 20, 4, 3, 17, 16, 20, 2, 20, 20],
#       'awayRoster': ['Lamar Jackson',
#                      'Zach Ertz',
#                      'Davante Adams',
#                      'Keenan Allen',
#                      'Raheem Mostert',
#                      'Marvin Jones Jr.',
#                      'DeVante Parker',
#                      'Robby Anderson',
#                      'Josh Lambo',
#                      'Washington D/ST',
#                      'Kerryon Johnson',
#                      'David Montgomery',
#                      'Hayden Hurst',
#                      'Matthew Stafford'],
#       'awayRosterScore': [13.0,
#                           10.5,
#                           0.0,
#                           23.5,
#                           0.0,
#                           6.5,
#                           8.5,
#                           7.5,
#                           0.0,
#                           1.0,
#                           2.5,
#                           5.0,
#                           6.5,
#                           18.0],
#       'awayScore': 69.0,
#       'awayTeamId': 2,
#       'homeLineup': [0, 2, 3, 4, 3, 20, 20, 20, 6, 17, 16, 20, 20],
#       'homeRoster': ['Dak Prescott',
#                      'Nick Chubb',
#                      'Kenyan Drake',
#                      'Robert Woods',
#                      'Stefon Diggs',
#                      'Mark Ingram II',
#                      'Sterling Shepard',
#                      'Preston Williams',
#                      'Austin Hooper',
#                      'Harrison Butker',
#                      'Broncos D/ST',
#                      "N'Keal Harry",
#                      'Sammy Watkins'],
#       'homeRosterScore': [26.0,
#                           22.5,
#                           7.5,
#                           18.5,
#                           12.0,
#                           3.0,
#                           0.0,
#                           7.0,
#                           3.5,
#                           3.0,
#                           3.0,
#                           4.0,
#                           9.5],
#       'homeScore': 96.0,
#       'homeTeamId': 8,
#       'week': 3,
#       'winner': 8},
#  18: {'awayLineup': [3, 20, 2, 4, 20, 20, 3, 16, 17, 6, 20, 20, 0, 20],
#       'awayRoster': ['Chris Carson',
#                      'Julio Jones',
#                      'Josh Jacobs',
#                      'Amari Cooper',
#                      'A.J. Brown',
#                      "D'Andre Swift",
#                      'Diontae Johnson',
#                      '49ers D/ST',
#                      'Wil Lutz',
#                      'Darren Waller',
#                      'Tom Brady',
#                      'Dalton Schultz',
#                      'Josh Allen',
#                      'Laviska Shenault Jr.'],
#       'awayRosterScore': [8.5,
#                           0.0,
#                           7.5,
#                           12.5,
#                           0.0,
#                           1.5,
#                           0.0,
#                           13.0,
#                           13.0,
#                           1.0,
#                           23.0,
#                           6.0,
#                           30.0,
#                           5.5],
#       'awayScore': 85.5,
#       'awayTeamId': 11,
#       'homeLineup': [4, 20, 21, 3, 3, 20, 21, 17, 20, 0, 20, 2, 16, 20, 20, 6],
#       'homeRoster': ['DeAndre Hopkins',
#                      'DJ Chark Jr.',
#                      'George Kittle',
#                      'Melvin Gordon III',
#                      'Julian Edelman',
#                      'CeeDee Lamb',
#                      'Damien Harris',
#                      'Greg Zuerlein',
#                      'Jerry Jeudy',
#                      'Cam Newton',
#                      'Malcolm Brown',
#                      'James Robinson',
#                      'Cardinals D/ST',
#                      'Dion Lewis',
#                      'Myles Gaskin',
#                      'Logan Thomas'],
#       'homeRosterScore': [18.0,
#                           0.0,
#                           0.0,
#                           5.0,
#                           3.0,
#                           8.5,
#                           0.0,
#                           9.0,
#                           7.5,
#                           10.0,
#                           1.0,
#                           27.0,
#                           4.0,
#                           1.5,
#                           10.5,
#                           5.0],
#       'homeScore': 81.0,
#       'homeTeamId': 1,
#       'week': 3,
#       'winner': 11},
#  19: {'awayLineup': [2, 21, 6, 4, 3, 3, 0, 17, 20, 20, 20, 16, 20, 20, 20],
#       'awayRoster': ['Alvin Kamara',
#                      'Christian McCaffrey',
#                      'Travis Kelce',
#                      'Cooper Kupp',
#                      'Terry McLaurin',
#                      'Tyler Boyd',
#                      'Aaron Rodgers',
#                      'Joey Slye',
#                      'Mike Gesicki',
#                      'Jared Goff',
#                      'Zack Moss',
#                      'Jets D/ST',
#                      'Chris Godwin',
#                      'T.J. Hockenson',
#                      'Laviska Shenault Jr.'],
#       'awayRosterScore': [18.5,
#                           0.0,
#                           8.5,
#                           14.5,
#                           16.0,
#                           12.5,
#                           29.0,
#                           6.0,
#                           1.5,
#                           12.0,
#                           0.0,
#                           8.0,
#                           0.0,
#                           9.0,
#                           10.5],
#       'awayScore': 113.0,
#       'awayTeamId': 4,
#       'homeLineup': [4, 20, 20, 20, 20, 3, 20, 17, 2, 6, 21, 0, 3, 16, 20],
#       'homeRoster': ['Mike Evans',
#                      'James Conner',
#                      'A.J. Green',
#                      'James White',
#                      'Golden Tate',
#                      'Darrell Henderson Jr.',
#                      'DeSean Jackson',
#                      'Robbie Gould',
#                      'Austin Ekeler',
#                      'Tyler Higbee',
#                      "Le'Veon Bell",
#                      'Deshaun Watson',
#                      'Darius Slayton',
#                      'Browns D/ST',
#                      'Eric Ebron'],
#       'homeRosterScore': [21.5,
#                           0.0,
#                           0.5,
#                           8.5,
#                           4.0,
#                           3.5,
#                           0.0,
#                           2.0,
#                           1.5,
#                           3.5,
#                           0.0,
#                           20.0,
#                           5.5,
#                           -1.0,
#                           0.0],
#       'homeScore': 56.5,
#       'homeTeamId': 9,
#       'week': 4,
#       'winner': 4},
#  20: {'awayLineup': [4, 2, 3, 3, 20, 0, 20, 20, 20, 20, 20, 17, 16, 6],
#       'awayRoster': ['Tyreek Hill',
#                      'Joe Mixon',
#                      'Aaron Jones',
#                      'Todd Gurley II',
#                      'Jarvis Landry',
#                      'Russell Wilson',
#                      'Henry Ruggs III',
#                      'Jamison Crowder',
#                      'Steelers D/ST',
#                      'Russell Gage',
#                      'Will Fuller V',
#                      'Sam Sloman',
#                      'Saints D/ST',
#                      'Rob Gronkowski'],
#       'awayRosterScore': [14.0,
#                           39.0,
#                           19.5,
#                           17.5,
#                           11.5,
#                           20.0,
#                           0.0,
#                           13.5,
#                           0.0,
#                           3.0,
#                           19.0,
#                           5.0,
#                           6.0,
#                           2.5],
#       'awayScore': 123.5,
#       'awayTeamId': 10,
#       'homeLineup': [20, 4, 2, 3, 3, 20, 17, 20, 0, 20, 16, 20, 6, 20],
#       'homeRoster': ['Leonard Fournette',
#                      'Odell Beckham Jr.',
#                      'Jonathan Taylor',
#                      'Marquise Brown',
#                      'Deebo Samuel',
#                      'Sony Michel',
#                      'Rodrigo Blankenship',
#                      'Colts D/ST',
#                      'Joe Burrow',
#                      'Mo Alie-Cox',
#                      'Rams D/ST',
#                      'Tee Higgins',
#                      'Hunter Henry',
#                      'Jamaal Williams'],
#       'homeRosterScore': [0.0,
#                           35.5,
#                           7.5,
#                           10.0,
#                           5.5,
#                           0.0,
#                           14.0,
#                           8.0,
#                           15.0,
#                           7.5,
#                           12.0,
#                           10.0,
#                           4.0,
#                           14.0],
#       'homeScore': 103.5,
#       'homeTeamId': 7,
#       'week': 4,
#       'winner': 10},
#  21: {'awayLineup': [3, 4, 20, 3, 20, 20, 0, 20, 16, 20, 20, 17, 2, 6],
#       'awayRoster': ['Miles Sanders',
#                      'Allen Robinson II',
#                      'David Johnson',
#                      'DK Metcalf',
#                      'Evan Engram',
#                      'Brandin Cooks',
#                      'Matt Ryan',
#                      'John Brown',
#                      'Ravens D/ST',
#                      'Curtis Samuel',
#                      'Mike Williams',
#                      'Zane Gonzalez',
#                      'James Robinson',
#                      'George Kittle'],
#       'awayRosterScore': [8.0,
#                           19.5,
#                           9.0,
#                           12.0,
#                           6.0,
#                           0.0,
#                           12.0,
#                           6.0,
#                           6.0,
#                           6.5,
#                           0.0,
#                           3.0,
#                           12.0,
#                           31.5],
#       'awayScore': 104.0,
#       'awayTeamId': 5,
#       'homeLineup': [2, 3, 20, 20, 20, 0, 17, 20, 20, 20, 16, 4, 3, 6],
#       'homeRoster': ['Dalvin Cook',
#                      'Adam Thielen',
#                      'DJ Moore',
#                      'T.Y. Hilton',
#                      'Cam Akers',
#                      'Kyler Murray',
#                      'Justin Tucker',
#                      'J.K. Dobbins',
#                      'Jonnu Smith',
#                      'Joshua Kelley',
#                      'Buccaneers D/ST',
#                      'Tyler Lockett',
#                      'Ezekiel Elliott',
#                      'Chris Herndon'],
#       'homeRosterScore': [27.0,
#                           21.0,
#                           6.0,
#                           3.5,
#                           0.0,
#                           22.0,
#                           8.0,
#                           1.5,
#                           0.0,
#                           1.5,
#                           6.0,
#                           4.0,
#                           16.0,
#                           1.5],
#       'homeScore': 105.5,
#       'homeTeamId': 3,
#       'week': 4,
#       'winner': 3},
#  22: {'awayLineup': [20, 0, 21, 2, 4, 3, 6, 20, 20, 20, 16, 17, 3, 20],
#       'awayRoster': ['Michael Thomas',
#                      'Patrick Mahomes',
#                      'Courtland Sutton',
#                      'Devin Singletary',
#                      'Michael Gallup',
#                      'Ronald Jones II',
#                      'Noah Fant',
#                      'Rex Burkhead',
#                      'Stephen Gostkowski',
#                      'Jeff Wilson Jr.',
#                      'Bills D/ST',
#                      'Jake Elliott',
#                      'Jerry Jeudy',
#                      'Nick Mullens'],
#       'awayRosterScore': [0.0,
#                           19.0,
#                           0.0,
#                           15.5,
#                           3.0,
#                           15.0,
#                           5.5,
#                           4.5,
#                           0.0,
#                           1.5,
#                           5.0,
#                           5.0,
#                           13.0,
#                           6.0],
#       'awayScore': 81.0,
#       'awayTeamId': 12,
#       'homeLineup': [0, 6, 20, 3, 20, 20, 3, 20, 2, 20, 20, 17, 16, 4],
#       'homeRoster': ['Lamar Jackson',
#                      'Zach Ertz',
#                      'Davante Adams',
# ...
#                      'Justin Jefferson',
#                      'Hunter Henry',
#                      'Ezekiel Elliott',
#                      'Antonio Brown',
#                      'J.D. McKissic',
#                      'Devonta Freeman',
#                      'Logan Thomas',
#                      'Jason Myers',
#                      'DeAndre Washington'],
#       'awayRosterScore': [2.0,
#                           9.5,
#                           3.0,
#                           20.0,
#                           0.0,
#                           23.5,
#                           7.0,
#                           7.0,
#                           6.0,
#                           6.5,
#                           8.0,
#                           0.0,
#                           7.0,
#                           11.0,
#                           5.0],
#       'awayScore': 178.0,
#       'awayTeamId': 1,
#       'homeLineup': [4, 3, 20, 20, 3, 21, 17, 2, 20, 20, 0, 20, 16, 6, 20],
#       'homeRoster': ['Mike Evans',
#                      'James Conner',
#                      'A.J. Green',
#                      'James White',
#                      'Darrell Henderson Jr.',
#                      'DeSean Jackson',
#                      'Robbie Gould',
#                      'Austin Ekeler',
#                      'Tyler Higbee',
#                      "Le'Veon Bell",
#                      'Deshaun Watson',
#                      'Darius Slayton',
#                      'Browns D/ST',
#                      'Eric Ebron',
#                      'Michael Badgley'],
#       'homeRosterScore': [6.5,
#                           1.0,
#                           15.0,
#                           1.5,
#                           0.0,
#                           0.0,
#                           1.0,
#                           17.5,
#                           4.0,
#                           4.0,
#                           15.0,
#                           4.5,
#                           2.0,
#                           6.0,
#                           9.0],
#       'homeScore': 94.5,
#       'homeTeamId': 9,
#       'week': 13,
#       'winner': 1},
#  91: {'awayLineup': [20, 2, 4, 3, 3, 6, 20, 0, 20, 21, 21, 20, 20, 20, 16, 17],
#       'awayRoster': ['Julio Jones',
#                      'Josh Jacobs',
#                      'A.J. Brown',
#                      "D'Andre Swift",
#                      'Diontae Johnson',
#                      'Darren Waller',
#                      'Tom Brady',
#                      'Josh Allen',
#                      'Daniel Carlson',
#                      'Michael Thomas',
#                      'Cam Akers',
#                      'T.Y. Hilton',
#                      'Emmanuel Sanders',
#                      'Buccaneers D/ST',
#                      'Saints D/ST',
#                      'Cairo Santos'],
#       'awayRosterScore': [0.0,
#                           6.0,
#                           6.0,
#                           6.0,
#                           17.0,
#                           13.5,
#                           29.0,
#                           31.0,
#                           13.0,
#                           0.0,
#                           0.0,
#                           7.5,
#                           11.0,
#                           14.0,
#                           0.0,
#                           12.0],
#       'awayScore': 222.5,
#       'awayTeamId': 11,
#       'homeLineup': [2, 3, 0, 17, 20, 20, 6, 20, 3, 4, 20, 20, 20, 16],
#       'homeRoster': ['Dalvin Cook',
#                      'Adam Thielen',
#                      'Kyler Murray',
#                      'Justin Tucker',
#                      'Jonnu Smith',
#                      'Tyler Lockett',
#                      'Dallas Goedert',
#                      'Chase Edmonds',
#                      'Nick Chubb',
#                      'DeAndre Hopkins',
#                      'Damien Harris',
#                      'Harrison Butker',
#                      '49ers D/ST',
#                      'Bills D/ST'],
#       'homeRosterScore': [15.0,
#                           19.0,
#                           14.0,
#                           9.0,
#                           10.5,
#                           5.5,
#                           4.5,
#                           1.0,
#                           13.5,
#                           8.0,
#                           0.0,
#                           7.0,
#                           9.0,
#                           8.0],
#       'homeScore': 218.0,
#       'homeTeamId': 3,
#       'week': 14,
#       'winner': 11},
#  92: {'awayLineup': [3, 3, 2, 4, 20, 20, 0, 21, 16, 20, 20, 6, 17, 20, 20],
#       'awayRoster': ['Miles Sanders',
#                      'Allen Robinson II',
#                      'David Johnson',
#                      'DK Metcalf',
#                      'Evan Engram',
#                      'Brandin Cooks',
#                      'Matt Ryan',
#                      'John Brown',
#                      'Ravens D/ST',
#                      'Curtis Samuel',
#                      'James Robinson',
#                      'George Kittle',
#                      'Wil Lutz',
#                      'Taysom Hill',
#                      'Chiefs D/ST'],
#       'awayRosterScore': [15.0,
#                           15.0,
#                           26.5,
#                           8.0,
#                           9.5,
#                           23.5,
#                           20.0,
#                           0.0,
#                           11.0,
#                           17.5,
#                           0.0,
#                           11.0,
#                           10.0,
#                           8.5,
#                           6.0],
#       'awayScore': 201.0,
#       'awayTeamId': 5,
#       'homeLineup': [4, 21, 2, 20, 20, 0, 20, 16, 6, 17, 3, 20, 20, 20, 3],
#       'homeRoster': ['Tyreek Hill',
#                      'Joe Mixon',
#                      'Aaron Jones',
#                      'Todd Gurley II',
#                      'Jarvis Landry',
#                      'Russell Wilson',
#                      'Jamison Crowder',
#                      'Steelers D/ST',
#                      'Rob Gronkowski',
#                      'Younghoe Koo',
#                      'Giovani Bernard',
#                      'Duke Johnson',
#                      'Kalen Ballage',
#                      'Keke Coutee',
#                      'Marvin Jones Jr.'],
#       'homeRosterScore': [8.0,
#                           0.0,
#                           11.0,
#                           5.5,
#                           0.0,
#                           19.0,
#                           24.5,
#                           8.0,
#                           18.0,
#                           1.0,
#                           15.5,
#                           0.0,
#                           3.0,
#                           7.5,
#                           2.5],
#       'homeScore': 186.5,
#       'homeTeamId': 10,
#       'week': 14,
#       'winner': 5},
#  93: {'awayLineup': [0, 20, 4, 20, 3, 20, 2, 20, 16, 20, 20, 3, 17, 6],
#       'awayRoster': ['Lamar Jackson',
#                      'Zach Ertz',
#                      'Davante Adams',
#                      'Keenan Allen',
#                      'Raheem Mostert',
#                      'Robby Anderson',
#                      'David Montgomery',
#                      'Hayden Hurst',
#                      'Bears D/ST',
#                      'Justin Herbert',
#                      'Jamaal Williams',
#                      'J.K. Dobbins',
#                      'Stephen Gostkowski',
#                      'Gerald Everett'],
#       'awayRosterScore': [21.0,
#                           4.5,
#                           37.5,
#                           0.0,
#                           0.0,
#                           12.5,
#                           18.0,
#                           12.5,
#                           8.0,
#                           16.0,
#                           0.0,
#                           13.0,
#                           2.0,
#                           2.0],
#       'awayScore': 197.0,
#       'awayTeamId': 2,
#       'homeLineup': [2, 20, 6, 4, 20, 0, 3, 3, 20, 20, 20, 16, 20, 17],
#       'homeRoster': ['Alvin Kamara',
#                      'Christian McCaffrey',
#                      'Travis Kelce',
#                      'Cooper Kupp',
#                      'Terry McLaurin',
#                      'Aaron Rodgers',
#                      'Zack Moss',
#                      'Chris Godwin',
#                      'T.J. Hockenson',
#                      'Clyde Edwards-Helaire',
#                      'Ben Roethlisberger',
#                      'Dolphins D/ST',
#                      'Deebo Samuel',
#                      'Joey Slye'],
#       'homeRosterScore': [53.5,
#                           0.0,
#                           18.5,
#                           10.0,
#                           0.0,
#                           24.0,
#                           11.5,
#                           16.5,
#                           4.0,
#                           0.0,
#                           25.0,
#                           2.0,
#                           0.0,
#                           2.0],
#       'homeScore': 234.5,
#       'homeTeamId': 4,
#       'week': 14,
#       'winner': 4},
#  94: {'awayLineup': [0, 20, 6, 20, 20, 2, 4, 20, 16, 17, 20, 3, 3],
#       'awayRoster': ['Patrick Mahomes',
#                      'Ronald Jones II',
#                      'Noah Fant',
#                      'Jerry Jeudy',
#                      'Chase Claypool',
#                      'Chris Carson',
#                      'Amari Cooper',
#                      'Jakobi Meyers',
#                      'Washington D/ST',
#                      'Tyler Bass',
#                      'Devontae Booker',
#                      'Brandon Aiyuk',
#                      'Jeff Wilson Jr.'],
#       'awayRosterScore': [19.0,
#                           0.0,
#                           9.0,
#                           9.0,
#                           7.0,
#                           8.5,
#                           14.0,
#                           6.0,
#                           10.0,
#                           8.0,
#                           2.0,
#                           2.5,
#                           26.5],
#       'awayScore': 185.5,
#       'awayTeamId': 12,
#       'homeLineup': [21, 2, 3, 4, 20, 6, 16, 20, 3, 0, 20, 20, 17, 20, 20],
#       'homeRoster': ['Dak Prescott',
#                      'Kenyan Drake',
#                      'Robert Woods',
#                      'Stefon Diggs',
#                      'Preston Williams',
#                      'Austin Hooper',
#                      'Broncos D/ST',
#                      'Sammy Watkins',
#                      'Nyheim Hines',
#                      'Ryan Tannehill',
#                      'DJ Moore',
#                      'Jimmy Graham',
#                      'Matt Prater',
#                      'Rex Burkhead',
#                      'Marquise Brown'],
#       'homeRosterScore': [0.0,
#                           11.0,
#                           6.0,
#                           36.5,
#                           0.0,
#                           10.5,
#                           2.0,
#                           0.0,
#                           8.0,
#                           15.0,
#                           5.5,
#                           20.0,
#                           1.0,
#                           0.0,
#                           10.0],
#       'homeScore': 187.0,
#       'homeTeamId': 8,
#       'week': 14,
#       'winner': 8},
#  95: {'awayLineup': [20, 20, 20, 16, 21, 2, 4, 20, 20, 3, 3, 21, 6, 17, 20, 0],
#       'awayRoster': ['DJ Chark Jr.',
#                      'Melvin Gordon III',
#                      'Cam Newton',
#                      'Cardinals D/ST',
#                      'Myles Gaskin',
#                      'Mike Davis',
#                      'Justin Jefferson',
#                      'Hunter Henry',
#                      'Ezekiel Elliott',
#                      'Antonio Brown',
#                      'J.D. McKissic',
#                      'Devonta Freeman',
#                      'Logan Thomas',
#                      'Jason Myers',
#                      'DeAndre Washington',
#                      'Jared Goff'],
#       'awayRosterScore': [14.0,
#                           7.0,
#                           9.0,
#                           4.0,
#                           30.5,
#                           8.0,
#                           11.0,
#                           0.0,
#                           15.0,
#                           11.0,
#                           18.0,
#                           0.0,
#                           9.5,
#                           10.0,
#                           0.0,
#                           9.0],
#       'awayScore': 184.0,
#       'awayTeamId': 1,
#       'homeLineup': [21, 2, 3, 20, 20, 4, 3, 20, 20, 17, 20, 0, 6, 20, 16],
#       'homeRoster': ['Saquon Barkley',
#                      'Derrick Henry',
#                      'JuJu Smith-Schuster',
#                      'Kenny Golladay',
#                      'Mark Andrews',
#                      'Calvin Ridley',
#                      'Kareem Hunt',
#                      'Antonio Gibson',
#                      'Jerick McKinnon',
#                      'Jason Sanders',
#                      'Christian Kirk',
#                      'Kirk Cousins',
#                      'Robert Tonyan',
#                      'Chargers D/ST',
#                      'Vikings D/ST'],
#       'homeRosterScore': [0.0,
#                           9.0,
#                           19.5,
#                           0.0,
#                           10.0,
#                           15.5,
#                           12.5,
#                           7.5,
#                           3.5,
#                           15.0,
#                           10.5,
#                           23.0,
#                           1.5,
#                           6.0,
#                           -8.0],
#       'homeScore': 170.5,
#       'homeTeamId': 6,
#       'week': 14,
#       'winner': 1},
#  96: {'awayLineup': [3, 2, 17, 16, 20, 4, 20, 20, 20, 3, 20, 0, 20, 6],
#       'awayRoster': ['Leonard Fournette',
#                      'Jonathan Taylor',
#                      'Rodrigo Blankenship',
#                      'Colts D/ST',
#                      'Tee Higgins',
#                      'CeeDee Lamb',
#                      'Wayne Gallman',
#                      'Seahawks D/ST',
#                      'Derek Carr',
#                      'Corey Davis',
#                      'Tua Tagovailoa',
#                      'Jalen Hurts',
#                      'Jared Cook',
#                      'Mike Gesicki'],
#       'awayRosterScore': [13.5,
#                           19.0,
#                           6.0,
#                           -1.0,
#                           18.0,
#                           20.5,
#                           5.0,
#                           8.0,
#                           23.0,
#                           0.0,
#                           8.0,
#                           17.0,
#                           9.5,
#                           7.0],
#       'awayScore': 160.0,
#       'awayTeamId': 7,
#       'homeLineup': [4, 3, 20, 20, 21, 17, 2, 20, 3, 0, 20, 16, 6, 20, 20],
#       'homeRoster': ['Mike Evans',
#                      'James Conner',
#                      'James White',
#                      'Darrell Henderson Jr.',
#                      'DeSean Jackson',
#                      'Robbie Gould',
#                      'Austin Ekeler',
#                      'Tyler Higbee',
#                      "Le'Veon Bell",
#                      'Deshaun Watson',
#                      'Darius Slayton',
#                      'Browns D/ST',
#                      'Eric Ebron',
#                      'Michael Badgley',
#                      'Benny Snell Jr.'],
#       'homeRosterScore': [35.0,
#                           14.5,
#                           4.5,
#                           6.0,
#                           14.5,
#                           0.0,
#                           13.5,
#                           4.5,
#                           3.5,
#                           25.0,
#                           3.0,
#                           6.0,
#                           12.5,
#                           14.0,
#                           0.0],
#       'homeScore': 198.5,
#       'homeTeamId': 9,
#       'week': 14,
#       'winner': 9}}
