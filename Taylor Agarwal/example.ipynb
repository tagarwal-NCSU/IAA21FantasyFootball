# %%
from ESPNAPI import League
import pprint

# year = "2021"
# leagueID = "2132617421"
# espn_s2 = "AEBlmW%2BnPlQPu68%2B3lzmpbsb5hNTRKEtHrL%2Bq8FkioyJ%2BAkHtJm7yYEagGmtwT%2BH4Wb9lhRdwJzDvYyDuUQ8huceOylAFUJtO3MVkxn0EsDJk47eyalQUduQyirWQiRoByYOp%2Bjhc8pG4Gfi2KftR2%2FBXgElrd734Lz0TBXCYDb33tB3PQt8S1Q6GcdZZ757%2BMeBz%2Fd87XfRCkn3Kgs%2FnB40EJtzL30SlEPeKBmB%2ByUdrysHbYZz9ESlKSIkBuey92sudtrZvPf5NUAIoAOmX2Py7fM1V1E%2F0zHImDLRUcar%2Bw%3D%3D"
# swid = "{9AED192A-A64B-4ECA-9772-BDDE2396067C}"

year = "2020"
leagueID = "139889"
espn_s2 = "AEBVAY4IP16BsQVvRgpY1hGOur4OKjZCVh6vfBIibHEoA5BHQCg3rZGBvbNbuESU3bQlfQzdveoAqNcmIhoBoO10gq2K%2FOhtdYamn6aQBihs%2FydsgoJehuJgLwAIdcaXlnehxcpTltR58fP0cX18vjZReJjo0OjZGUSOr3ff0Iuz1Ztt8c4rUkFJVTd8cEd%2BT76%2Bvva8s5iQGAfKTUfPA9P2k6xC33qYcaH%2FIYykwIC00PKoJOlysod9yM5bUrA39lpJ2WZQfdICgqXt5zu%2FYaDpiXVznvExI4BIoEFnEVfs3w%3D%3D"
swid = "{65C194B8-D67C-4A07-8990-988E5F391434}"

My_League = League(year, leagueID, espn_s2, swid)

reader = pprint.PrettyPrinter()
#pd.DataFrame.from_dict(IAA_League.fetch_teams(), orient = 'index')
print("--Teams--")
reader.pprint(My_League.fetch_teams())
print("--Rosters--")
reader.pprint(My_League.fetch_rosters())
print("--Matchups--")
reader.pprint(My_League.fetch_matchups())
print("--Matchup Rosters--")
reader.pprint(My_League.fetch_matchup_rosters())
# Out:
# --Teams--
# {1: {'acquisitions': 30,
#      'drops': 27,
#      'ownerNames': 'Adam Boghosian, noah henley',
#      'pointsAgainst': 1117.5,
#      'pointsFor': 955.5,
#      'record': '4-0-8',
#      'teamName': 'PEAKY PUGGLES',
#      'trades': 6,
#      'winPercentage': 0.3333333333333333},
#  2: {'acquisitions': 31,
#      'drops': 32,
#      'ownerNames': 'Andrew Wolschlag',
#      'pointsAgainst': 1070.0,
#      'pointsFor': 1094.0,
#      'record': '6-0-6',
#      'teamName': 'Pickle Ricks',
#      'trades': 1,
#      'winPercentage': 0.5},
#  3: {'acquisitions': 32,
#      'drops': 28,
#      'ownerNames': 'Alvin Ong',
#      'pointsAgainst': 1045.0,
#      'pointsFor': 1365.0,
#      'record': '12-0-0',
#      'teamName': 'Emperor Vin',
#      'trades': 7,
#      'winPercentage': 1.0},
#  4: {'acquisitions': 25,
#      'drops': 25,
#      'ownerNames': 'Priyank Purohit',
#      'pointsAgainst': 1067.5,
#      'pointsFor': 1313.0,
#      'record': '8-0-4',
#      'teamName': 'Bollywood Beast Mode',
#      'trades': 2,
#      'winPercentage': 0.6666666666666666},
#  5: {'acquisitions': 8,
#      'drops': 7,
#      'ownerNames': 'Kyle Griffin, Troy Blaser',
#      'pointsAgainst': 1151.5,
#      'pointsFor': 1182.0,
#      'record': '6-0-6',
#      'teamName': 'Haha Clinton "Hold Muh" Dix',
#      'trades': 1,
#      'winPercentage': 0.5},
#  6: {'acquisitions': 23,
#      'drops': 22,
#      'ownerNames': 'Wesley Clark',
#      'pointsAgainst': 1185.0,
#      'pointsFor': 1161.0,
#      'record': '4-0-8',
#      'teamName': 'The 4FLs Punching Bag',
#      'trades': 0,
#      'winPercentage': 0.3333333333333333},
#  7: {'acquisitions': 41,
#      'drops': 40,
#      'ownerNames': 'Brian Rauf',
#      'pointsAgainst': 1215.5,
#      'pointsFor': 904.5,
#      'record': '2-0-10',
#      'teamName': 'Suburban Dad',
#      'trades': 3,
#      'winPercentage': 0.16666666666666666},
#  8: {'acquisitions': 9,
#      'drops': 6,
#      'ownerNames': 'Sam Rossabi',
#      'pointsAgainst': 1096.0,
#      'pointsFor': 1021.0,
#      'record': '6-0-6',
#      'teamName': 'Goonfield Gnarbarians',
#      'trades': 1,
#      'winPercentage': 0.5},
#  9: {'acquisitions': 6,
#      'drops': 6,
#      'ownerNames': 'james earle, Daniel Christan',
#      'pointsAgainst': 1146.0,
#      'pointsFor': 962.0,
#      'record': '3-0-9',
#      'teamName': 'Hurst Jmearles ',
#      'trades': 2,
#      'winPercentage': 0.25},
#  10: {'acquisitions': 17,
#       'drops': 16,
#       'ownerNames': 'sean walsh',
#       'pointsAgainst': 1184.0,
#       'pointsFor': 1338.0,
#       'record': '8-0-4',
#       'teamName': 'Kibbls And Vick',
#       'trades': 1,
#       'winPercentage': 0.6666666666666666},
#  11: {'acquisitions': 25,
#       'drops': 21,
#       'ownerNames': 'Brad Snipes',
#       'pointsAgainst': 998.5,
#       'pointsFor': 1154.5,
#       'record': '8-0-4',
#       'teamName': 'Scared Turtle',
#       'trades': 3,
#       'winPercentage': 0.6666666666666666},
#  12: {'acquisitions': 56,
#       'drops': 55,
#       'ownerNames': 'Matt Peterson',
#       'pointsAgainst': 1180.0,
#       'pointsFor': 1006.0,
#       'record': '5-0-7',
#       'teamName': 'Wall Street Pete',
#       'trades': 3,
#       'winPercentage': 0.4166666666666667}}
# --Rosters--
# {1: {'players': ['DJ Chark Jr.',
#                  'Melvin Gordon III',
#                  'Cam Newton',
#                  'Cardinals D/ST',
#                  'Myles Gaskin',
#                  'Mike Davis',
#                  'Justin Jefferson',
#                  'Hunter Henry',
#                  'Ezekiel Elliott',
#                  'Antonio Brown',
#                  'J.D. McKissic',
#                  'Devonta Freeman',
#                  'Logan Thomas',
#                  'Jason Myers',
#                  'DeAndre Washington',
#                  'Jared Goff'],
#      'positions': [3, 2, 1, 16, 2, 2, 3, 4, 2, 3, 2, 2, 4, 5, 2, 1]},
#  2: {'players': ['Lamar Jackson',
#                  'Zach Ertz',
#                  'Davante Adams',
#                  'Keenan Allen',
#                  'Raheem Mostert',
#                  'Robby Anderson',
#                  'David Montgomery',
#                  'Hayden Hurst',
#                  'Bears D/ST',
#                  'Justin Herbert',
#                  'Jamaal Williams',
#                  'J.K. Dobbins',
#                  'Stephen Gostkowski',
#                  'Gerald Everett'],
#      'positions': [1, 4, 3, 3, 2, 3, 2, 4, 16, 1, 2, 2, 5, 4]},
#  3: {'players': ['Dalvin Cook',
#                  'Adam Thielen',
#                  'Kyler Murray',
#                  'Justin Tucker',
#                  'Jonnu Smith',
#                  'Tyler Lockett',
#                  'Dallas Goedert',
#                  'Chase Edmonds',
#                  'Nick Chubb',
#                  'DeAndre Hopkins',
#                  'Damien Harris',
#                  'Harrison Butker',
#                  '49ers D/ST',
#                  'Bills D/ST'],
#      'positions': [2, 3, 1, 5, 4, 3, 4, 2, 2, 3, 2, 5, 16, 16]},
#  4: {'players': ['Alvin Kamara',
#                  'Christian McCaffrey',
#                  'Travis Kelce',
#                  'Cooper Kupp',
#                  'Terry McLaurin',
#                  'Aaron Rodgers',
#                  'Zack Moss',
#                  'Chris Godwin',
#                  'T.J. Hockenson',
#                  'Clyde Edwards-Helaire',
#                  'Ben Roethlisberger',
#                  'Dolphins D/ST',
#                  'Deebo Samuel',
#                  'Joey Slye'],
#      'positions': [2, 2, 4, 3, 3, 1, 2, 3, 4, 2, 1, 16, 3, 5]},
#  5: {'players': ['Miles Sanders',
#                  'Allen Robinson II',
#                  'David Johnson',
#                  'DK Metcalf',
#                  'Evan Engram',
#                  'Brandin Cooks',
#                  'Matt Ryan',
#                  'John Brown',
#                  'Ravens D/ST',
#                  'Curtis Samuel',
#                  'James Robinson',
#                  'George Kittle',
#                  'Wil Lutz',
#                  'Taysom Hill',
#                  'Chiefs D/ST'],
#      'positions': [2, 3, 2, 3, 4, 3, 1, 3, 16, 3, 2, 4, 5, 1, 16]},
#  6: {'players': ['Saquon Barkley',
#                  'Derrick Henry',
#                  'JuJu Smith-Schuster',
#                  'Kenny Golladay',
#                  'Mark Andrews',
#                  'Calvin Ridley',
#                  'Kareem Hunt',
#                  'Antonio Gibson',
#                  'Jerick McKinnon',
#                  'Jason Sanders',
#                  'Christian Kirk',
#                  'Kirk Cousins',
#                  'Robert Tonyan',
#                  'Chargers D/ST',
#                  'Vikings D/ST'],
#      'positions': [2, 2, 3, 3, 4, 3, 2, 2, 2, 5, 3, 1, 4, 16, 16]},
#  7: {'players': ['Leonard Fournette',
#                  'Jonathan Taylor',
#                  'Rodrigo Blankenship',
#                  'Colts D/ST',
#                  'Tee Higgins',
#                  'CeeDee Lamb',
#                  'Wayne Gallman',
#                  'Seahawks D/ST',
#                  'Derek Carr',
#                  'Corey Davis',
#                  'Tua Tagovailoa',
#                  'Jalen Hurts',
#                  'Jared Cook',
#                  'Mike Gesicki'],
#      'positions': [2, 2, 5, 16, 3, 3, 2, 16, 1, 3, 1, 1, 4, 4]},
#  8: {'players': ['Dak Prescott',
#                  'Kenyan Drake',
#                  'Robert Woods',
#                  'Stefon Diggs',
#                  'Preston Williams',
#                  'Austin Hooper',
#                  'Broncos D/ST',
#                  'Sammy Watkins',
#                  'Nyheim Hines',
#                  'Ryan Tannehill',
#                  'DJ Moore',
#                  'Jimmy Graham',
#                  'Matt Prater',
#                  'Rex Burkhead',
#                  'Marquise Brown'],
#      'positions': [1, 2, 3, 3, 3, 4, 16, 3, 2, 1, 3, 4, 5, 2, 3]},
#  9: {'players': ['Mike Evans',
#                  'James Conner',
#                  'James White',
#                  'Darrell Henderson Jr.',
#                  'DeSean Jackson',
#                  'Robbie Gould',
#                  'Austin Ekeler',
#                  'Tyler Higbee',
#                  "Le'Veon Bell",
#                  'Deshaun Watson',
#                  'Darius Slayton',
#                  'Browns D/ST',
#                  'Eric Ebron',
#                  'Michael Badgley',
#                  'Benny Snell Jr.'],
#      'positions': [3, 2, 2, 2, 3, 5, 2, 4, 2, 1, 3, 16, 4, 5, 2]},
#  10: {'players': ['Tyreek Hill',
#                   'Joe Mixon',
#                   'Aaron Jones',
#                   'Todd Gurley II',
#                   'Jarvis Landry',
#                   'Russell Wilson',
#                   'Jamison Crowder',
#                   'Steelers D/ST',
#                   'Rob Gronkowski',
#                   'Younghoe Koo',
#                   'Giovani Bernard',
#                   'Duke Johnson',
#                   'Kalen Ballage',
#                   'Keke Coutee',
#                   'Marvin Jones Jr.'],
#       'positions': [3, 2, 2, 2, 3, 1, 3, 16, 4, 5, 2, 2, 2, 3, 3]},
#  11: {'players': ['Julio Jones',
#                   'Josh Jacobs',
#                   'A.J. Brown',
#                   "D'Andre Swift",
#                   'Diontae Johnson',
#                   'Darren Waller',
#                   'Tom Brady',
#                   'Josh Allen',
#                   'Daniel Carlson',
#                   'Michael Thomas',
#                   'Cam Akers',
#                   'T.Y. Hilton',
#                   'Emmanuel Sanders',
#                   'Buccaneers D/ST',
#                   'Saints D/ST',
#                   'Cairo Santos'],
#       'positions': [3, 2, 3, 2, 3, 4, 1, 1, 5, 3, 2, 3, 3, 16, 16, 5]},
#  12: {'players': ['Patrick Mahomes',
#                   'Ronald Jones II',
#                   'Noah Fant',
#                   'Jerry Jeudy',
#                   'Chase Claypool',
#                   'Chris Carson',
#                   'Amari Cooper',
#                   'Jakobi Meyers',
#                   'Washington D/ST',
#                   'Tyler Bass',
#                   'Devontae Booker',
#                   'Brandon Aiyuk',
#                   'Jeff Wilson Jr.'],
#       'positions': [1, 2, 4, 3, 3, 2, 3, 3, 16, 5, 2, 3, 2]}}
# --Matchups--
# {1: {'awayScore': 67.5,
#      'awayTeamId': 9,
#      'homeScore': 75.0,
#      'homeTeamId': 12,
#      'week': 1,
#      'winner': 12},
#  2: {'awayScore': 112.5,
#      'awayTeamId': 5,
#      'homeScore': 129.5,
#      'homeTeamId': 6,
#      'week': 1,
#      'winner': 6},
#  3: {'awayScore': 103.5,
#      'awayTeamId': 10,
#      'homeScore': 75.5,
#      'homeTeamId': 8,
#      'week': 1,
#      'winner': 10},
#  4: {'awayScore': 125.5,
#      'awayTeamId': 4,
#      'homeScore': 81.0,
#      'homeTeamId': 1,
#      'week': 1,
#      'winner': 4},
#  5: {'awayScore': 68.5,
#      'awayTeamId': 7,
#      'homeScore': 114.5,
#      'homeTeamId': 11,
#      'week': 1,
#      'winner': 11},
#  6: {'awayScore': 111.5,
#      'awayTeamId': 3,
#      'homeScore': 102.5,
#      'homeTeamId': 2,
#      'week': 1,
#      'winner': 3},
#  7: {'awayScore': 109.0,
#      'awayTeamId': 5,
#      'homeScore': 88.5,
#      'homeTeamId': 9,
#      'week': 2,
#      'winner': 5},
#  8: {'awayScore': 75.5,
#      'awayTeamId': 12,
#      'homeScore': 145.5,
#      'homeTeamId': 10,
#      'week': 2,
#      'winner': 10},
#  9: {'awayScore': 65.5,
#      'awayTeamId': 6,
#      'homeScore': 127.5,
#      'homeTeamId': 4,
#      'week': 2,
#      'winner': 4},
#  10: {'awayScore': 117.0,
#       'awayTeamId': 8,
#       'homeScore': 68.5,
#       'homeTeamId': 7,
#       'week': 2,
#       'winner': 8},
#  11: {'awayScore': 99.5,
#       'awayTeamId': 1,
#       'homeScore': 137.0,
#       'homeTeamId': 3,
#       'week': 2,
#       'winner': 3},
#  12: {'awayScore': 85.5,
#       'awayTeamId': 11,
#       'homeScore': 67.5,
#       'homeTeamId': 2,
#       'week': 2,
#       'winner': 11},
#  13: {'awayScore': 126.0,
#       'awayTeamId': 9,
#       'homeScore': 107.0,
#       'homeTeamId': 10,
#       'week': 3,
#       'winner': 9},
#  14: {'awayScore': 138.0,
#       'awayTeamId': 4,
#       'homeScore': 88.5,
#       'homeTeamId': 5,
#       'week': 3,
#       'winner': 4},
#  15: {'awayScore': 82.5,
#       'awayTeamId': 7,
#       'homeScore': 106.0,
#       'homeTeamId': 12,
#       'week': 3,
#       'winner': 12},
#  16: {'awayScore': 138.0,
#       'awayTeamId': 3,
#       'homeScore': 115.5,
#       'homeTeamId': 6,
#       'week': 3,
#       'winner': 3},
#  17: {'awayScore': 69.0,
#       'awayTeamId': 2,
#       'homeScore': 96.0,
#       'homeTeamId': 8,
#       'week': 3,
#       'winner': 8},
#  18: {'awayScore': 85.5,
#       'awayTeamId': 11,
#       'homeScore': 81.0,
#       'homeTeamId': 1,
#       'week': 3,
#       'winner': 11},
#  19: {'awayScore': 113.0,
#       'awayTeamId': 4,
#       'homeScore': 56.5,
#       'homeTeamId': 9,
#       'week': 4,
#       'winner': 4},
#  20: {'awayScore': 123.5,
#       'awayTeamId': 10,
#       'homeScore': 103.5,
#       'homeTeamId': 7,
#       'week': 4,
#       'winner': 10},
#  21: {'awayScore': 104.0,
#       'awayTeamId': 5,
#       'homeScore': 105.5,
#       'homeTeamId': 3,
#       'week': 4,
#       'winner': 3},
#  22: {'awayScore': 81.0,
#       'awayTeamId': 12,
#       'homeScore': 78.5,
#       'homeTeamId': 2,
#       'week': 4,
#       'winner': 12},
#  23: {'awayScore': 90.0,
#       'awayTeamId': 6,
#       'homeScore': 110.5,
#       'homeTeamId': 11,
#       'week': 4,
#       'winner': 11},
#  24: {'awayScore': 89.5,
#       'awayTeamId': 8,
#       'homeScore': 87.0,
#       'homeTeamId': 1,
#       'week': 4,
#       'winner': 8},
#  25: {'awayScore': 104.5,
#       'awayTeamId': 9,
#       'homeScore': 81.5,
#       'homeTeamId': 7,
#       'week': 5,
#       'winner': 9},
#  26: {'awayScore': 130.0,
#       'awayTeamId': 3,
#       'homeScore': 83.0,
#       'homeTeamId': 4,
#       'week': 5,
#       'winner': 3},
#  27: {'awayScore': 80.5,
#       'awayTeamId': 2,
#       'homeScore': 102.0,
#       'homeTeamId': 10,
#       'week': 5,
#       'winner': 10},
#  28: {'awayScore': 78.0,
#       'awayTeamId': 11,
#       'homeScore': 111.5,
#       'homeTeamId': 5,
#       'week': 5,
#       'winner': 5},
#  29: {'awayScore': 109.5,
#       'awayTeamId': 1,
#       'homeScore': 80.5,
#       'homeTeamId': 12,
#       'week': 5,
#       'winner': 1},
#  30: {'awayScore': 85.5,
#       'awayTeamId': 8,
#       'homeScore': 116.0,
#       'homeTeamId': 6,
#       'week': 5,
#       'winner': 6},
#  31: {'awayScore': 111.5,
#       'awayTeamId': 3,
#       'homeScore': 79.0,
#       'homeTeamId': 9,
#       'week': 6,
#       'winner': 3},
#  32: {'awayScore': 77.0,
#       'awayTeamId': 7,
#       'homeScore': 79.5,
#       'homeTeamId': 2,
#       'week': 6,
#       'winner': 2},
#  33: {'awayScore': 68.0,
#       'awayTeamId': 4,
#       'homeScore': 123.5,
#       'homeTeamId': 11,
#       'week': 6,
#       'winner': 11},
#  34: {'awayScore': 92.0,
#       'awayTeamId': 10,
#       'homeScore': 100.0,
#       'homeTeamId': 1,
#       'week': 6,
#       'winner': 1},
#  35: {'awayScore': 107.0,
#       'awayTeamId': 5,
#       'homeScore': 98.5,
#       'homeTeamId': 8,
#       'week': 6,
#       'winner': 5},
#  36: {'awayScore': 99.5,
#       'awayTeamId': 12,
#       'homeScore': 99.0,
#       'homeTeamId': 6,
#       'week': 6,
#       'winner': 12},
#  37: {'awayScore': 69.5,
#       'awayTeamId': 9,
#       'homeScore': 134.0,
#       'homeTeamId': 2,
#       'week': 7,
#       'winner': 2},
#  38: {'awayScore': 85.0,
#       'awayTeamId': 11,
#       'homeScore': 126.0,
#       'homeTeamId': 3,
#       'week': 7,
#       'winner': 3},
#  39: {'awayScore': 57.5,
#       'awayTeamId': 1,
#       'homeScore': 96.0,
#       'homeTeamId': 7,
#       'week': 7,
#       'winner': 7},
#  40: {'awayScore': 45.0,
#       'awayTeamId': 8,
#       'homeScore': 121.0,
#       'homeTeamId': 4,
#       'week': 7,
#       'winner': 4},
#  41: {'awayScore': 96.0,
#       'awayTeamId': 6,
#       'homeScore': 110.5,
#       'homeTeamId': 10,
#       'week': 7,
#       'winner': 10},
#  42: {'awayScore': 52.5,
#       'awayTeamId': 12,
#       'homeScore': 114.5,
#       'homeTeamId': 5,
#       'week': 7,
#       'winner': 5},
#  43: {'awayScore': 87.0,
#       'awayTeamId': 11,
#       'homeScore': 63.5,
#       'homeTeamId': 9,
#       'week': 8,
#       'winner': 11},
#  44: {'awayScore': 98.0,
#       'awayTeamId': 2,
#       'homeScore': 59.5,
#       'homeTeamId': 1,
#       'week': 8,
#       'winner': 2},
#  45: {'awayScore': 96.5,
#       'awayTeamId': 3,
#       'homeScore': 79.5,
#       'homeTeamId': 8,
#       'week': 8,
#       'winner': 3},
#  46: {'awayScore': 64.5,
#       'awayTeamId': 7,
#       'homeScore': 48.0,
#       'homeTeamId': 6,
#       'week': 8,
#       'winner': 7},
#  47: {'awayScore': 101.5,
#       'awayTeamId': 4,
#       'homeScore': 92.5,
#       'homeTeamId': 12,
#       'week': 8,
#       'winner': 4},
#  48: {'awayScore': 126.5,
#       'awayTeamId': 10,
#       'homeScore': 113.5,
#       'homeTeamId': 5,
#       'week': 8,
#       'winner': 10},
#  49: {'awayScore': 54.5,
#       'awayTeamId': 9,
#       'homeScore': 58.5,
#       'homeTeamId': 1,
#       'week': 9,
#       'winner': 1},
#  50: {'awayScore': 61.5,
#       'awayTeamId': 8,
#       'homeScore': 105.0,
#       'homeTeamId': 11,
#       'week': 9,
#       'winner': 11},
#  51: {'awayScore': 74.5,
#       'awayTeamId': 6,
#       'homeScore': 105.5,
#       'homeTeamId': 2,
#       'week': 9,
#       'winner': 2},
#  52: {'awayScore': 87.5,
#       'awayTeamId': 12,
#       'homeScore': 110.0,
#       'homeTeamId': 3,
#       'week': 9,
#       'winner': 3},
#  53: {'awayScore': 102.5,
#       'awayTeamId': 5,
#       'homeScore': 65.0,
#       'homeTeamId': 7,
#       'week': 9,
#       'winner': 5},
#  54: {'awayScore': 96.5,
#       'awayTeamId': 10,
#       'homeScore': 133.5,
#       'homeTeamId': 4,
#       'week': 9,
#       'winner': 4},
#  55: {'awayScore': 89.0,
#       'awayTeamId': 8,
#       'homeScore': 65.0,
#       'homeTeamId': 9,
#       'week': 10,
#       'winner': 8},
#  56: {'awayScore': 72.5,
#       'awayTeamId': 1,
#       'homeScore': 78.0,
#       'homeTeamId': 6,
#       'week': 10,
#       'winner': 6},
#  57: {'awayScore': 115.0,
#       'awayTeamId': 11,
#       'homeScore': 68.0,
#       'homeTeamId': 12,
#       'week': 10,
#       'winner': 11},
#  58: {'awayScore': 83.0,
#       'awayTeamId': 2,
#       'homeScore': 52.0,
#       'homeTeamId': 5,
#       'week': 10,
#       'winner': 2},
#  59: {'awayScore': 107.0,
#       'awayTeamId': 3,
#       'homeScore': 67.0,
#       'homeTeamId': 10,
#       'week': 10,
#       'winner': 3},
#  60: {'awayScore': 79.5,
#       'awayTeamId': 7,
#       'homeScore': 107.5,
#       'homeTeamId': 4,
#       'week': 10,
#       'winner': 4},
#  61: {'awayScore': 108.0,
#       'awayTeamId': 9,
#       'homeScore': 96.0,
#       'homeTeamId': 6,
#       'week': 11,
#       'winner': 9},
#  62: {'awayScore': 78.0,
#       'awayTeamId': 12,
#       'homeScore': 99.5,
#       'homeTeamId': 8,
#       'week': 11,
#       'winner': 8},
#  63: {'awayScore': 71.0,
#       'awayTeamId': 5,
#       'homeScore': 92.5,
#       'homeTeamId': 1,
#       'week': 11,
#       'winner': 1},
#  64: {'awayScore': 103.0,
#       'awayTeamId': 10,
#       'homeScore': 90.0,
#       'homeTeamId': 11,
#       'week': 11,
#       'winner': 10},
#  65: {'awayScore': 100.5,
#       'awayTeamId': 4,
#       'homeScore': 113.0,
#       'homeTeamId': 2,
#       'week': 11,
#       'winner': 2},
#  66: {'awayScore': 67.5,
#       'awayTeamId': 7,
#       'homeScore': 102.0,
#       'homeTeamId': 3,
#       'week': 11,
#       'winner': 3},
#  79: {'awayScore': 83.0,
#       'awayTeamId': 2,
#       'homeScore': 161.0,
#       'homeTeamId': 10,
#       'week': 12,
#       'winner': 10},
#  80: {'awayScore': 94.0,
#       'awayTeamId': 4,
#       'homeScore': 96.0,
#       'homeTeamId': 5,
#       'week': 12,
#       'winner': 5},
#  81: {'awayScore': 79.5,
#       'awayTeamId': 9,
#       'homeScore': 84.5,
#       'homeTeamId': 8,
#       'week': 12,
#       'winner': 8},
#  82: {'awayScore': 90.0,
#       'awayTeamId': 3,
#       'homeScore': 75.0,
#       'homeTeamId': 11,
#       'week': 12,
#       'winner': 3},
#  83: {'awayScore': 153.0,
#       'awayTeamId': 6,
#       'homeScore': 50.5,
#       'homeTeamId': 7,
#       'week': 12,
#       'winner': 6},
#  84: {'awayScore': 57.0,
#       'awayTeamId': 1,
#       'homeScore': 110.0,
#       'homeTeamId': 12,
#       'week': 12,
#       'winner': 12},
#  85: {'awayScore': 149.0,
#       'awayTeamId': 5,
#       'homeScore': 216.0,
#       'homeTeamId': 3,
#       'week': 13,
#       'winner': 3},
#  86: {'awayScore': 213.0,
#       'awayTeamId': 11,
#       'homeScore': 160.0,
#       'homeTeamId': 10,
#       'week': 13,
#       'winner': 11},
#  87: {'awayScore': 203.5,
#       'awayTeamId': 2,
#       'homeScore': 165.5,
#       'homeTeamId': 8,
#       'week': 13,
#       'winner': 2},
#  88: {'awayScore': 174.0,
#       'awayTeamId': 12,
#       'homeScore': 212.0,
#       'homeTeamId': 4,
#       'week': 13,
#       'winner': 4},
#  89: {'awayScore': 203.0,
#       'awayTeamId': 7,
#       'homeScore': 204.0,
#       'homeTeamId': 6,
#       'week': 13,
#       'winner': 6},
#  90: {'awayScore': 178.0,
#       'awayTeamId': 1,
#       'homeScore': 94.5,
#       'homeTeamId': 9,
#       'week': 13,
#       'winner': 1},
#  91: {'awayScore': 222.5,
#       'awayTeamId': 11,
#       'homeScore': 218.0,
#       'homeTeamId': 3,
#       'week': 14,
#       'winner': 11},
#  92: {'awayScore': 201.0,
#       'awayTeamId': 5,
#       'homeScore': 186.5,
#       'homeTeamId': 10,
#       'week': 14,
#       'winner': 5},
#  93: {'awayScore': 197.0,
#       'awayTeamId': 2,
#       'homeScore': 234.5,
#       'homeTeamId': 4,
#       'week': 14,
#       'winner': 4},
#  94: {'awayScore': 185.5,
#       'awayTeamId': 12,
#       'homeScore': 187.0,
#       'homeTeamId': 8,
#       'week': 14,
#       'winner': 8},
#  95: {'awayScore': 184.0,
#       'awayTeamId': 1,
#       'homeScore': 170.5,
#       'homeTeamId': 6,
#       'week': 14,
#       'winner': 1},
#  96: {'awayScore': 160.0,
#       'awayTeamId': 7,
#       'homeScore': 198.5,
#       'homeTeamId': 9,
#       'week': 14,
#       'winner': 9}}
# --Matchup Rosters--
# {1: {'awayLineup': [20, 2, 3, 3, 4, 6, 20, 0, 20, 20, 20, 16, 20, 17],
#      'awayRoster': ['Mike Evans',
#                     'Clyde Edwards-Helaire',
#                     'Tyler Lockett',
#                     'James Conner',
#                     'A.J. Green',
#                     'Darren Waller',
#                     'James White',
#                     'Tom Brady',
#                     'Golden Tate',
#                     'Darrell Henderson Jr.',
#                     'DeSean Jackson',
#                     'Vikings D/ST',
#                     'Eric Ebron',
#                     'Robbie Gould'],
#      'awayRosterEligibleSlots': [[3, 4, 5, 23, 7, 20, 21],
#                                  [25, 2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [16, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [17, 20, 21]],
#      'awayRosterScore': [6.5,
#                          19.0,
#                          13.0,
#                          1.0,
#                          7.5,
#                          7.0,
#                          6.5,
#                          19.0,
#                          0.0,
#                          0.0,
#                          5.0,
#                          -9.0,
#                          1.5,
#                          10.0],
#      'awayScore': 67.5,
#      'awayTeamId': 9,
#      'homeLineup': [4, 0, 20, 2, 3, 3, 6, 20, 20, 20, 20, 20, 17, 16],
#      'homeRoster': ['Michael Thomas',
#                     'Patrick Mahomes',
#                     'Courtland Sutton',
#                     'Devin Singletary',
#                     'Michael Gallup',
#                     'Ronald Jones II',
#                     'Noah Fant',
#                     'Kerryon Johnson',
#                     'Emmanuel Sanders',
#                     'Mecole Hardman',
#                     'Bears D/ST',
#                     'Chris Thompson',
#                     'Chris Boswell',
#                     'Eagles D/ST'],
#      'homeRosterEligibleSlots': [[3, 4, 5, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [16, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [17, 20, 21],
#                                  [16, 20, 21]],
#      'homeRosterScore': [2.5,
#                          20.0,
#                          0.0,
#                          7.5,
#                          6.5,
#                          8.0,
#                          16.5,
#                          1.0,
#                          8.5,
#                          0.5,
#                          0.0,
#                          1.0,
#                          9.0,
#                          5.0],
#      'homeScore': 75.0,
#      'homeTeamId': 12,
#      'week': 1,
#      'winner': 12},
#  2: {'awayLineup': [20, 2, 4, 3, 3, 6, 20, 0, 20, 20, 16, 20, 20, 17],
#      'awayRoster': ['Miles Sanders',
#                     'Ezekiel Elliott',
#                     'Allen Robinson II',
#                     'David Johnson',
#                     'DK Metcalf',
#                     'Evan Engram',
#                     'Brandin Cooks',
#                     'Matt Ryan',
#                     'Jordan Howard',
#                     'John Brown',
#                     'Ravens D/ST',
#                     'Curtis Samuel',
#                     'Mike Williams',
#                     'Zane Gonzalez'],
#      'awayRosterEligibleSlots': [[2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [16, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [17, 20, 21]],
#      'awayRosterScore': [0.0,
#                          25.5,
#                          9.5,
#                          17.5,
#                          17.0,
#                          1.0,
#                          3.0,
#                          24.0,
#                          6.0,
#                          16.0,
#                          12.0,
#                          5.5,
#                          8.0,
#                          6.0],
#      'awayScore': 112.5,
#      'awayTeamId': 5,
#      'homeLineup': [2, 3, 4, 20, 6, 3, 20, 20, 20, 0, 16, 20, 20, 17],
#      'homeRoster': ['Saquon Barkley',
#                     'Derrick Henry',
#                     'JuJu Smith-Schuster',
#                     'Kenny Golladay',
#                     'Mark Andrews',
#                     'Calvin Ridley',
#                     'Kareem Hunt',
#                     'Antonio Gibson',
#                     'Rob Gronkowski',
#                     'Drew Brees',
#                     'Patriots D/ST',
#                     'Tevin Coleman',
#                     'LeSean McCoy',
#                     'Matt Prater'],
#      'homeRosterEligibleSlots': [[2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [16, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [17, 20, 21]],
#      'homeRosterScore': [9.0,
#                          13.5,
#                          21.0,
#                          0.0,
#                          19.5,
#                          29.5,
#                          9.0,
#                          4.0,
#                          2.0,
#                          14.0,
#                          12.0,
#                          1.5,
#                          0.5,
#                          11.0],
#      'homeScore': 129.5,
#      'homeTeamId': 6,
#      'week': 1,
#      'winner': 6},
#  3: {'awayLineup': [4, 2, 3, 3, 20, 0, 6, 20, 20, 16, 20, 20, 17, 20],
#      'awayRoster': ['Tyreek Hill',
#                     'Joe Mixon',
#                     'Aaron Jones',
#                     'Todd Gurley II',
#                     'Jarvis Landry',
#                     'Russell Wilson',
#                     'Jared Cook',
#                     'Henry Ruggs III',
#                     'Jamison Crowder',
#                     'Steelers D/ST',
#                     'Alexander Mattison',
#                     'Joe Burrow',
#                     'Younghoe Koo',
#                     'Darrynton Evans'],
#      'awayRosterEligibleSlots': [[3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [25, 3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [16, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [25, 0, 7, 20, 21],
#                                  [17, 20, 21],
#                                  [25, 2, 3, 23, 7, 20, 21]],
#      'awayRosterScore': [12.5,
#                          4.5,
#                          15.0,
#                          12.0,
#                          8.5,
#                          30.0,
#                          10.5,
#                          7.5,
#                          20.5,
#                          10.0,
#                          10.0,
#                          15.0,
#                          9.0,
#                          0.0],
#      'awayScore': 103.5,
#      'awayTeamId': 10,
#      'homeLineup': [0, 2, 3, 4, 3, 20, 20, 20, 6, 17, 16, 20, 20],
#      'homeRoster': ['Dak Prescott',
#                     'Nick Chubb',
#                     'Kenyan Drake',
#                     'Robert Woods',
#                     'Stefon Diggs',
#                     'Mark Ingram II',
#                     'Sterling Shepard',
#                     'Preston Williams',
#                     'Austin Hooper',
#                     'Harrison Butker',
#                     'Broncos D/ST',
#                     "N'Keal Harry",
#                     'Sammy Watkins'],
#      'homeRosterEligibleSlots': [[0, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [17, 20, 21],
#                                  [16, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21]],
#      'homeRosterScore': [17.0,
#                          4.5,
#                          13.0,
#                          14.0,
#                          12.0,
#                          2.0,
#                          7.0,
#                          5.0,
#                          2.0,
#                          10.0,
#                          3.0,
#                          3.5,
#                          17.5],
#      'homeScore': 75.5,
#      'homeTeamId': 8,
#      'week': 1,
#      'winner': 10},
#  4: {'awayLineup': [2, 3, 6, 4, 3, 20, 20, 20, 20, 0, 20, 17, 20, 16],
#      'awayRoster': ['Alvin Kamara',
#                     'Christian McCaffrey',
#                     'Travis Kelce',
#                     'Cooper Kupp',
#                     'Terry McLaurin',
#                     'Hunter Henry',
#                     'Tyler Boyd',
#                     'Christian Kirk',
#                     'Marlon Mack',
#                     'Aaron Rodgers',
#                     'Latavius Murray',
#                     'Jason Myers',
#                     'O.J. Howard',
#                     'Chargers D/ST'],
#      'awayRosterEligibleSlots': [[2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [17, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [16, 20, 21]],
#      'awayRosterScore': [20.5,
#                          25.5,
#                          14.0,
#                          6.0,
#                          8.5,
#                          9.5,
#                          5.0,
#                          0.5,
#                          6.5,
#                          30.0,
#                          4.0,
#                          9.0,
#                          11.0,
#                          12.0],
#      'awayScore': 125.5,
#      'awayTeamId': 4,
#      'homeLineup': [4, 3, 6, 20, 3, 20, 20, 20, 21, 2, 17, 20, 20, 0, 16],
#      'homeRoster': ['DeAndre Hopkins',
#                     'DJ Chark Jr.',
#                     'George Kittle',
#                     'Melvin Gordon III',
#                     'Julian Edelman',
#                     'CeeDee Lamb',
#                     'Matt Breida',
#                     'Chase Edmonds',
#                     'Damien Harris',
#                     'Boston Scott',
#                     'Greg Zuerlein',
#                     'Jordan Love',
#                     'Jerry Jeudy',
#                     'Cam Newton',
#                     'Lions D/ST'],
#      'homeRosterEligibleSlots': [[3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [25, 3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [17, 20, 21],
#                                  [25, 0, 7, 20, 21],
#                                  [25, 3, 4, 5, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [16, 20, 21]],
#      'homeRosterScore': [22.0,
#                          9.5,
#                          6.0,
#                          12.5,
#                          9.5,
#                          7.5,
#                          2.0,
#                          10.5,
#                          0.0,
#                          5.0,
#                          4.0,
#                          0.0,
#                          7.0,
#                          25.0,
#                          0.0],
#      'homeScore': 81.0,
#      'homeTeamId': 1,
#      'week': 1,
#      'winner': 4},
#  5: {'awayLineup': [4, 2, 3, 3, 20, 20, 20, 6, 16, 20, 0, 17, 20, 20],
#      'awayRoster': ['Chris Godwin',
#                     'Leonard Fournette',
#                     'Odell Beckham Jr.',
#                     'Jonathan Taylor',
#                     'Marquise Brown',
#                     'Will Fuller V',
#                     'Deebo Samuel',
#                     'T.J. Hockenson',
#                     'Bills D/ST',
#                     'Sony Michel',
#                     'Carson Wentz',
#                     'Rodrigo Blankenship',
#                     'Dallas Goedert',
#                     'Bryan Edwards'],
#      'awayRosterEligibleSlots': [[3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [25, 2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [16, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [25, 17, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [25, 3, 4, 5, 23, 7, 20, 21]],
#      'awayRosterScore': [10.0,
#                          1.5,
#                          3.5,
#                          11.0,
#                          12.5,
#                          15.0,
#                          0.0,
#                          13.5,
#                          10.0,
#                          9.0,
#                          12.0,
#                          7.0,
#                          20.0,
#                          0.5],
#      'awayScore': 68.5,
#      'awayTeamId': 7,
#      'homeLineup': [3, 4, 2, 20, 0, 3, 20, 20, 20, 6, 16, 20, 20, 17],
#      'homeRoster': ['Chris Carson',
#                     'Julio Jones',
#                     'Josh Jacobs',
#                     'Amari Cooper',
#                     'Deshaun Watson',
#                     'A.J. Brown',
#                     "D'Andre Swift",
#                     'David Montgomery',
#                     'Diontae Johnson',
#                     'Hayden Hurst',
#                     '49ers D/ST',
#                     'Darius Slayton',
#                     'Mike Gesicki',
#                     'Wil Lutz'],
#      'homeRosterEligibleSlots': [[2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [25, 2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [16, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [17, 20, 21]],
#      'homeRosterScore': [21.0,
#                          19.5,
#                          33.0,
#                          13.0,
#                          20.0,
#                          5.5,
#                          8.5,
#                          7.5,
#                          6.0,
#                          4.5,
#                          1.0,
#                          25.0,
#                          4.5,
#                          10.0],
#      'homeScore': 114.5,
#      'homeTeamId': 11,
#      'week': 1,
#      'winner': 11},
#  6: {'awayLineup': [2, 3, 4, 3, 20, 20, 20, 0, 6, 20, 17, 16, 20, 20],
#      'awayRoster': ['Austin Ekeler',
#                     'Dalvin Cook',
#                     'Adam Thielen',
#                     'DJ Moore',
#                     "Le'Veon Bell",
#                     'T.Y. Hilton',
#                     'Cam Akers',
#                     'Kyler Murray',
#                     'Tyler Higbee',
#                     'Zack Moss',
#                     'Justin Tucker',
#                     'Colts D/ST',
#                     'J.K. Dobbins',
#                     'Jonnu Smith'],
#      'awayRosterEligibleSlots': [[2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [25, 2, 3, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [25, 2, 3, 23, 7, 20, 21],
#                                  [17, 20, 21],
#                                  [16, 20, 21],
#                                  [25, 2, 3, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21]],
#      'awayRosterScore': [8.5,
#                          21.5,
#                          28.0,
#                          7.0,
#                          5.0,
#                          7.0,
#                          3.5,
#                          26.0,
#                          5.5,
#                          9.5,
#                          9.0,
#                          6.0,
#                          14.0,
#                          11.0],
#      'awayScore': 111.5,
#      'awayTeamId': 3,
#      'homeLineup': [0, 6, 4, 3, 2, 3, 20, 20, 20, 20, 20, 20, 16, 17],
#      'homeRoster': ['Lamar Jackson',
#                     'Zach Ertz',
#                     'Davante Adams',
#                     'Keenan Allen',
#                     'Raheem Mostert',
#                     'Marvin Jones Jr.',
#                     'Phillip Lindsay',
#                     'DeVante Parker',
#                     'Tarik Cohen',
#                     'Matthew Stafford',
#                     'Robby Anderson',
#                     'Duke Johnson',
#                     'Cowboys D/ST',
#                     'Austin Seibert'],
#      'homeRosterEligibleSlots': [[0, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [16, 20, 21],
#                                  [17, 20, 21]],
#      'homeRosterScore': [27.0,
#                          8.5,
#                          34.0,
#                          5.0,
#                          22.0,
#                          7.0,
#                          3.5,
#                          6.0,
#                          5.0,
#                          15.0,
#                          22.0,
#                          1.0,
#                          0.0,
#                          -1.0],
#      'homeScore': 102.5,
#      'homeTeamId': 2,
#      'week': 1,
#      'winner': 3},
#  7: {'awayLineup': [3, 2, 4, 3, 20, 6, 20, 0, 20, 20, 16, 20, 20, 17],
#      'awayRoster': ['Miles Sanders',
#                     'Ezekiel Elliott',
#                     'Allen Robinson II',
#                     'David Johnson',
#                     'DK Metcalf',
#                     'Evan Engram',
#                     'Brandin Cooks',
#                     'Matt Ryan',
#                     'Jordan Howard',
#                     'John Brown',
#                     'Ravens D/ST',
#                     'Curtis Samuel',
#                     'Mike Williams',
#                     'Zane Gonzalez'],
#      'awayRosterEligibleSlots': [[2, 3, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [16, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [17, 20, 21]],
#      'awayRosterScore': [17.5,
#                          18.0,
#                          4.5,
#                          5.0,
#                          17.0,
#                          9.0,
#                          11.5,
#                          27.0,
#                          6.0,
#                          16.0,
#                          15.0,
#                          4.0,
#                          2.0,
#                          13.0],
#      'awayScore': 109.0,
#      'awayTeamId': 5,
#      'homeLineup': [3, 2, 3, 20, 4, 6, 20, 0, 20, 20, 20, 16, 20, 17],
#      'homeRoster': ['Mike Evans',
#                     'Clyde Edwards-Helaire',
#                     'Tyler Lockett',
#                     'James Conner',
#                     'A.J. Green',
#                     'Darren Waller',
#                     'James White',
#                     'Tom Brady',
#                     'Golden Tate',
#                     'Darrell Henderson Jr.',
#                     'DeSean Jackson',
#                     'Vikings D/ST',
#                     'Eric Ebron',
#                     'Robbie Gould'],
#      'homeRosterEligibleSlots': [[3, 4, 5, 23, 7, 20, 21],
#                                  [25, 2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [2, 3, 23, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
#                                  [16, 20, 21],
#                                  [5, 6, 23, 7, 20, 21],
#                                  [17, 20, 21]],
#      'homeRosterScore': [19.5,
#                          9.0,
#                          15.5,
#                          18.0,
#                          3.5,
#                          22.0,
#                          0.0,
#                          8.0,
#                          6.5,
#                          19.0,
#                          9.0,
#                          3.0,
#                          5.5,
#                          8.0],
#      'homeScore': 88.5,
#      'homeTeamId': 9,
#      'week': 2,
#      'winner': 5},
#  8: {'awayLineup': [21, 0, 20, 2, 3, 3, 6, 4, 20, 17, 20, 20, 20, 16],
#      'awayRoster': ['Michael Thomas',
#                     'Patrick Mahomes',
#                     'Courtland Sutton',
#                     'Devin Singletary',
#                     'Michael Gallup',
#                     'Ronald Jones II',
#                     'Noah Fant',
#                     'Emmanuel Sanders',
#                     'Mecole Hardman',
#                     'Chris Boswell',
#                     'Eagles D/ST',
#                     'Nyheim Hines',
#                     'Benny Snell Jr.',
#                     'Saints D/ST'],
#      'awayRosterEligibleSlots': [[3, 4, 5, 23, 7, 20, 21],
#                                  [0, 7, 20, 21],
#                                  [3, 4, 5, 23, 7, 20, 21],
# ...
#                           1.0,
#                           15.5,
#                           0.0,
#                           3.0,
#                           7.5,
#                           2.5],
#       'homeScore': 186.5,
#       'homeTeamId': 10,
#       'week': 14,
#       'winner': 5},
#  93: {'awayLineup': [0, 20, 4, 20, 3, 20, 2, 20, 16, 20, 20, 3, 17, 6],
#       'awayRoster': ['Lamar Jackson',
#                      'Zach Ertz',
#                      'Davante Adams',
#                      'Keenan Allen',
#                      'Raheem Mostert',
#                      'Robby Anderson',
#                      'David Montgomery',
#                      'Hayden Hurst',
#                      'Bears D/ST',
#                      'Justin Herbert',
#                      'Jamaal Williams',
#                      'J.K. Dobbins',
#                      'Stephen Gostkowski',
#                      'Gerald Everett'],
#       'awayRosterEligibleSlots': [[0, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [16, 20, 21],
#                                   [25, 0, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [25, 2, 3, 23, 7, 20, 21],
#                                   [17, 20, 21],
#                                   [5, 6, 23, 7, 20, 21]],
#       'awayRosterScore': [21.0,
#                           4.5,
#                           37.5,
#                           0.0,
#                           0.0,
#                           12.5,
#                           18.0,
#                           12.5,
#                           8.0,
#                           16.0,
#                           0.0,
#                           13.0,
#                           2.0,
#                           2.0],
#       'awayScore': 197.0,
#       'awayTeamId': 2,
#       'homeLineup': [2, 20, 6, 4, 20, 0, 3, 3, 20, 20, 20, 16, 20, 17],
#       'homeRoster': ['Alvin Kamara',
#                      'Christian McCaffrey',
#                      'Travis Kelce',
#                      'Cooper Kupp',
#                      'Terry McLaurin',
#                      'Aaron Rodgers',
#                      'Zack Moss',
#                      'Chris Godwin',
#                      'T.J. Hockenson',
#                      'Clyde Edwards-Helaire',
#                      'Ben Roethlisberger',
#                      'Dolphins D/ST',
#                      'Deebo Samuel',
#                      'Joey Slye'],
#       'homeRosterEligibleSlots': [[2, 3, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [0, 7, 20, 21],
#                                   [25, 2, 3, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [25, 2, 3, 23, 7, 20, 21],
#                                   [0, 7, 20, 21],
#                                   [16, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [17, 20, 21]],
#       'homeRosterScore': [53.5,
#                           0.0,
#                           18.5,
#                           10.0,
#                           0.0,
#                           24.0,
#                           11.5,
#                           16.5,
#                           4.0,
#                           0.0,
#                           25.0,
#                           2.0,
#                           0.0,
#                           2.0],
#       'homeScore': 234.5,
#       'homeTeamId': 4,
#       'week': 14,
#       'winner': 4},
#  94: {'awayLineup': [0, 20, 6, 20, 20, 2, 4, 20, 16, 17, 20, 3, 3],
#       'awayRoster': ['Patrick Mahomes',
#                      'Ronald Jones II',
#                      'Noah Fant',
#                      'Jerry Jeudy',
#                      'Chase Claypool',
#                      'Chris Carson',
#                      'Amari Cooper',
#                      'Jakobi Meyers',
#                      'Washington D/ST',
#                      'Tyler Bass',
#                      'Devontae Booker',
#                      'Brandon Aiyuk',
#                      'Jeff Wilson Jr.'],
#       'awayRosterEligibleSlots': [[0, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [25, 3, 4, 5, 23, 7, 20, 21],
#                                   [25, 3, 4, 5, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [16, 20, 21],
#                                   [25, 17, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [25, 3, 4, 5, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21]],
#       'awayRosterScore': [19.0,
#                           0.0,
#                           9.0,
#                           9.0,
#                           7.0,
#                           8.5,
#                           14.0,
#                           6.0,
#                           10.0,
#                           8.0,
#                           2.0,
#                           2.5,
#                           26.5],
#       'awayScore': 185.5,
#       'awayTeamId': 12,
#       'homeLineup': [21, 2, 3, 4, 20, 6, 16, 20, 3, 0, 20, 20, 17, 20, 20],
#       'homeRoster': ['Dak Prescott',
#                      'Kenyan Drake',
#                      'Robert Woods',
#                      'Stefon Diggs',
#                      'Preston Williams',
#                      'Austin Hooper',
#                      'Broncos D/ST',
#                      'Sammy Watkins',
#                      'Nyheim Hines',
#                      'Ryan Tannehill',
#                      'DJ Moore',
#                      'Jimmy Graham',
#                      'Matt Prater',
#                      'Rex Burkhead',
#                      'Marquise Brown'],
#       'homeRosterEligibleSlots': [[0, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [16, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [0, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [17, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21]],
#       'homeRosterScore': [0.0,
#                           11.0,
#                           6.0,
#                           36.5,
#                           0.0,
#                           10.5,
#                           2.0,
#                           0.0,
#                           8.0,
#                           15.0,
#                           5.5,
#                           20.0,
#                           1.0,
#                           0.0,
#                           10.0],
#       'homeScore': 187.0,
#       'homeTeamId': 8,
#       'week': 14,
#       'winner': 8},
#  95: {'awayLineup': [20, 20, 20, 16, 21, 2, 4, 20, 20, 3, 3, 21, 6, 17, 20, 0],
#       'awayRoster': ['DJ Chark Jr.',
#                      'Melvin Gordon III',
#                      'Cam Newton',
#                      'Cardinals D/ST',
#                      'Myles Gaskin',
#                      'Mike Davis',
#                      'Justin Jefferson',
#                      'Hunter Henry',
#                      'Ezekiel Elliott',
#                      'Antonio Brown',
#                      'J.D. McKissic',
#                      'Devonta Freeman',
#                      'Logan Thomas',
#                      'Jason Myers',
#                      'DeAndre Washington',
#                      'Jared Goff'],
#       'awayRosterEligibleSlots': [[3, 4, 5, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [0, 7, 20, 21],
#                                   [16, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [25, 3, 4, 5, 23, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [17, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [0, 7, 20, 21]],
#       'awayRosterScore': [14.0,
#                           7.0,
#                           9.0,
#                           4.0,
#                           30.5,
#                           8.0,
#                           11.0,
#                           0.0,
#                           15.0,
#                           11.0,
#                           18.0,
#                           0.0,
#                           9.5,
#                           10.0,
#                           0.0,
#                           9.0],
#       'awayScore': 184.0,
#       'awayTeamId': 1,
#       'homeLineup': [21, 2, 3, 20, 20, 4, 3, 20, 20, 17, 20, 0, 6, 20, 16],
#       'homeRoster': ['Saquon Barkley',
#                      'Derrick Henry',
#                      'JuJu Smith-Schuster',
#                      'Kenny Golladay',
#                      'Mark Andrews',
#                      'Calvin Ridley',
#                      'Kareem Hunt',
#                      'Antonio Gibson',
#                      'Jerick McKinnon',
#                      'Jason Sanders',
#                      'Christian Kirk',
#                      'Kirk Cousins',
#                      'Robert Tonyan',
#                      'Chargers D/ST',
#                      'Vikings D/ST'],
#       'homeRosterEligibleSlots': [[2, 3, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [17, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [0, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [16, 20, 21],
#                                   [16, 20, 21]],
#       'homeRosterScore': [0.0,
#                           9.0,
#                           19.5,
#                           0.0,
#                           10.0,
#                           15.5,
#                           12.5,
#                           7.5,
#                           3.5,
#                           15.0,
#                           10.5,
#                           23.0,
#                           1.5,
#                           6.0,
#                           -8.0],
#       'homeScore': 170.5,
#       'homeTeamId': 6,
#       'week': 14,
#       'winner': 1},
#  96: {'awayLineup': [3, 2, 17, 16, 20, 4, 20, 20, 20, 3, 20, 0, 20, 6],
#       'awayRoster': ['Leonard Fournette',
#                      'Jonathan Taylor',
#                      'Rodrigo Blankenship',
#                      'Colts D/ST',
#                      'Tee Higgins',
#                      'CeeDee Lamb',
#                      'Wayne Gallman',
#                      'Seahawks D/ST',
#                      'Derek Carr',
#                      'Corey Davis',
#                      'Tua Tagovailoa',
#                      'Jalen Hurts',
#                      'Jared Cook',
#                      'Mike Gesicki'],
#       'awayRosterEligibleSlots': [[2, 3, 23, 7, 20, 21],
#                                   [25, 2, 3, 23, 7, 20, 21],
#                                   [25, 17, 20, 21],
#                                   [16, 20, 21],
#                                   [25, 3, 4, 5, 23, 7, 20, 21],
#                                   [25, 3, 4, 5, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [16, 20, 21],
#                                   [0, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [25, 0, 7, 20, 21],
#                                   [25, 0, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21]],
#       'awayRosterScore': [13.5,
#                           19.0,
#                           6.0,
#                           -1.0,
#                           18.0,
#                           20.5,
#                           5.0,
#                           8.0,
#                           23.0,
#                           0.0,
#                           8.0,
#                           17.0,
#                           9.5,
#                           7.0],
#       'awayScore': 160.0,
#       'awayTeamId': 7,
#       'homeLineup': [4, 3, 20, 20, 21, 17, 2, 20, 3, 0, 20, 16, 6, 20, 20],
#       'homeRoster': ['Mike Evans',
#                      'James Conner',
#                      'James White',
#                      'Darrell Henderson Jr.',
#                      'DeSean Jackson',
#                      'Robbie Gould',
#                      'Austin Ekeler',
#                      'Tyler Higbee',
#                      "Le'Veon Bell",
#                      'Deshaun Watson',
#                      'Darius Slayton',
#                      'Browns D/ST',
#                      'Eric Ebron',
#                      'Michael Badgley',
#                      'Benny Snell Jr.'],
#       'homeRosterEligibleSlots': [[3, 4, 5, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [17, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [2, 3, 23, 7, 20, 21],
#                                   [0, 7, 20, 21],
#                                   [3, 4, 5, 23, 7, 20, 21],
#                                   [16, 20, 21],
#                                   [5, 6, 23, 7, 20, 21],
#                                   [17, 20, 21],
#                                   [2, 3, 23, 7, 20, 21]],
#       'homeRosterScore': [35.0,
#                           14.5,
#                           4.5,
#                           6.0,
#                           14.5,
#                           0.0,
#                           13.5,
#                           4.5,
#                           3.5,
#                           25.0,
#                           3.0,
#                           6.0,
#                           12.5,
#                           14.0,
#                           0.0],
#       'homeScore': 198.5,
#       'homeTeamId': 9,
#       'week': 14,
#       'winner': 9}}

# %%
year = "2021"
leagueID = "2132617421"
espn_s2 = "AEBlmW%2BnPlQPu68%2B3lzmpbsb5hNTRKEtHrL%2Bq8FkioyJ%2BAkHtJm7yYEagGmtwT%2BH4Wb9lhRdwJzDvYyDuUQ8huceOylAFUJtO3MVkxn0EsDJk47eyalQUduQyirWQiRoByYOp%2Bjhc8pG4Gfi2KftR2%2FBXgElrd734Lz0TBXCYDb33tB3PQt8S1Q6GcdZZ757%2BMeBz%2Fd87XfRCkn3Kgs%2FnB40EJtzL30SlEPeKBmB%2ByUdrysHbYZz9ESlKSIkBuey92sudtrZvPf5NUAIoAOmX2Py7fM1V1E%2F0zHImDLRUcar%2Bw%3D%3D"
swid = "{9AED192A-A64B-4ECA-9772-BDDE2396067C}"

IAA_League = League(year, leagueID, espn_s2, swid)

reader.pprint(IAA_League.fetch_draft())
# Out:
# {'draftDetail': {'drafted': False,
#                  'inProgress': True,
#                  'picks': [{'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 1,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 1,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 1,
#                             'teamId': 11,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 2,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 2,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 2,
#                             'teamId': 9,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 3,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 3,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 3,
#                             'teamId': 14,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 4,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 4,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 4,
#                             'teamId': 10,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 5,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 5,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 5,
#                             'teamId': 16,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 6,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 6,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 6,
#                             'teamId': 5,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 7,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 7,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 7,
#                             'teamId': 12,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 8,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 8,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 8,
#                             'teamId': 2,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 9,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 9,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 9,
#                             'teamId': 8,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 10,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 10,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 10,
#                             'teamId': 7,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 11,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 11,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 11,
#                             'teamId': 15,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 12,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 12,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 12,
#                             'teamId': 4,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 13,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 13,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 13,
#                             'teamId': 6,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 14,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 14,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 14,
#                             'teamId': 3,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 15,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 15,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 15,
#                             'teamId': 1,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 16,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 16,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 1,
#                             'roundPickNumber': 16,
#                             'teamId': 13,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 17,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 17,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 1,
#                             'teamId': 13,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 18,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 18,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 2,
#                             'teamId': 1,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 19,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 19,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 3,
#                             'teamId': 3,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 20,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 20,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 4,
#                             'teamId': 6,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 21,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 21,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 5,
#                             'teamId': 4,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 22,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 22,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 6,
#                             'teamId': 15,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 23,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 23,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 7,
#                             'teamId': 7,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 24,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 24,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 8,
#                             'teamId': 8,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 25,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 25,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 9,
#                             'teamId': 2,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 26,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 26,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 10,
#                             'teamId': 12,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 27,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 27,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 11,
#                             'teamId': 5,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 28,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 28,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 12,
#                             'teamId': 16,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 29,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 29,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 13,
#                             'teamId': 10,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 30,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 30,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 14,
#                             'teamId': 14,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 31,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 31,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 15,
#                             'teamId': 9,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 32,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 32,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 2,
#                             'roundPickNumber': 16,
#                             'teamId': 11,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 33,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 33,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 1,
#                             'teamId': 11,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 34,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 34,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 2,
#                             'teamId': 9,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 35,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 35,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 3,
#                             'teamId': 14,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 36,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 36,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 4,
#                             'teamId': 10,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 37,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 37,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 5,
#                             'teamId': 16,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 38,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 38,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 6,
#                             'teamId': 5,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 39,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 39,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 7,
#                             'teamId': 12,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 40,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 40,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 8,
#                             'teamId': 2,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 41,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 41,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 9,
#                             'teamId': 8,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 42,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 42,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 10,
#                             'teamId': 7,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 43,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 43,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 11,
#                             'teamId': 15,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 44,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 44,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 12,
#                             'teamId': 4,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 45,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 45,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 13,
#                             'teamId': 6,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 46,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 46,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 14,
#                             'teamId': 3,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 47,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 47,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 15,
#                             'teamId': 1,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 48,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 48,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 3,
#                             'roundPickNumber': 16,
#                             'teamId': 13,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 49,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 49,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 1,
#                             'teamId': 13,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 50,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 50,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 2,
#                             'teamId': 1,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 51,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 51,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 3,
#                             'teamId': 3,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 52,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 52,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 4,
#                             'teamId': 6,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 53,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 53,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 5,
#                             'teamId': 4,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 54,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 54,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 6,
#                             'teamId': 15,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 55,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 55,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 7,
#                             'teamId': 7,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 56,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 56,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 8,
#                             'teamId': 8,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 57,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 57,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 9,
#                             'teamId': 2,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 58,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 58,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 10,
#                             'teamId': 12,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 59,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 59,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 11,
#                             'teamId': 5,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 60,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 60,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 12,
#                             'teamId': 16,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 61,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 61,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 13,
#                             'teamId': 10,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 62,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 62,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 14,
#                             'teamId': 14,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 63,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 63,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 15,
#                             'teamId': 9,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 64,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 64,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 4,
#                             'roundPickNumber': 16,
#                             'teamId': 11,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 65,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 65,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 1,
#                             'teamId': 11,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 66,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 66,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 2,
#                             'teamId': 9,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 67,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 67,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 3,
#                             'teamId': 14,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 68,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 68,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 4,
#                             'teamId': 10,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 69,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 69,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 5,
#                             'teamId': 16,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 70,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 70,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 6,
#                             'teamId': 5,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 71,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 71,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 7,
#                             'teamId': 12,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 72,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 72,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 8,
#                             'teamId': 2,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 73,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 73,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 9,
#                             'teamId': 8,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 74,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 74,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 10,
#                             'teamId': 7,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 75,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 75,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 11,
#                             'teamId': 15,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 76,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 76,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 12,
#                             'teamId': 4,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 77,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 77,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 13,
#                             'teamId': 6,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 78,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 78,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 5,
#                             'roundPickNumber': 14,
#                             'teamId': 3,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 79,
# ...
#                             'roundId': 15,
#                             'roundPickNumber': 10,
#                             'teamId': 7,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 235,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 235,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 15,
#                             'roundPickNumber': 11,
#                             'teamId': 15,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 236,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 236,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 15,
#                             'roundPickNumber': 12,
#                             'teamId': 4,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 237,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 237,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 15,
#                             'roundPickNumber': 13,
#                             'teamId': 6,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 238,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 238,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 15,
#                             'roundPickNumber': 14,
#                             'teamId': 3,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 239,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 239,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 15,
#                             'roundPickNumber': 15,
#                             'teamId': 1,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 240,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 240,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 15,
#                             'roundPickNumber': 16,
#                             'teamId': 13,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 241,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 241,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 1,
#                             'teamId': 13,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 242,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 242,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 2,
#                             'teamId': 1,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 243,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 243,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 3,
#                             'teamId': 3,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 244,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 244,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 4,
#                             'teamId': 6,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 245,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 245,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 5,
#                             'teamId': 4,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 246,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 246,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 6,
#                             'teamId': 15,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 247,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 247,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 7,
#                             'teamId': 7,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 248,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 248,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 8,
#                             'teamId': 8,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 249,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 249,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 9,
#                             'teamId': 2,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 250,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 250,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 10,
#                             'teamId': 12,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 251,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 251,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 11,
#                             'teamId': 5,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 252,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 252,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 12,
#                             'teamId': 16,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 253,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 253,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 13,
#                             'teamId': 10,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 254,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 254,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 14,
#                             'teamId': 14,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 255,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 255,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 15,
#                             'teamId': 9,
#                             'tradeLocked': False},
#                            {'autoDraftTypeId': 0,
#                             'bidAmount': 0,
#                             'id': 256,
#                             'keeper': False,
#                             'lineupSlotId': 0,
#                             'nominatingTeamId': 0,
#                             'overallPickNumber': 256,
#                             'playerId': -1,
#                             'reservedForKeeper': False,
#                             'roundId': 16,
#                             'roundPickNumber': 16,
#                             'teamId': 11,
#                             'tradeLocked': False}]},
#  'gameId': 1,
#  'id': 2132617421,
#  'scoringPeriodId': 1,
#  'seasonId': 2021,
#  'segmentId': 0,
#  'settings': {'draftSettings': {'auctionBudget': 200,
#                                 'availableDate': 1630879200000,
#                                 'date': 1630882800000,
#                                 'isTradingEnabled': False,
#                                 'keeperCount': 0,
#                                 'keeperCountFuture': 0,
#                                 'keeperOrderType': 'TRADITIONAL',
#                                 'leagueSubType': 'NONE',
#                                 'orderType': 'DRAFT_START',
#                                 'pickOrder': [11,
#                                               9,
#                                               14,
#                                               10,
#                                               16,
#                                               5,
#                                               12,
#                                               2,
#                                               8,
#                                               7,
#                                               15,
#                                               4,
#                                               6,
#                                               3,
#                                               1,
#                                               13],
#                                 'timePerSelection': 90,
#                                 'type': 'SNAKE'}},
#  'status': {'activatedDate': 1627688944542,
#             'createdAsLeagueType': 3,
#             'currentLeagueType': 0,
#             'currentMatchupPeriod': 1,
#             'finalScoringPeriod': 18,
#             'firstScoringPeriod': 1,
#             'isActive': True,
#             'isExpired': False,
#             'isFull': True,
#             'isPlayoffMatchupEdited': False,
#             'isToBeDeleted': False,
#             'isViewable': False,
#             'isWaiverOrderEdited': False,
#             'latestScoringPeriod': 1,
#             'previousSeasons': [],
#             'teamsJoined': 16,
#             'transactionScoringPeriod': 0,
#             'waiverLastExecutionDate': 1630825912214,
#             'waiverProcessStatus': {}}}

# %%
reader.pprint(IAA_League.fetch_rosters())
# Out:
# {1: {'players': ['Tyreek Hill',
#                  'DK Metcalf',
#                  'Chase Edmonds',
#                  'Aaron Rodgers',
#                  'Noah Fant',
#                  'Buccaneers D/ST',
#                  'Cole Beasley',
#                  'Michael Carter',
#                  'Tua Tagovailoa',
#                  'Malcolm Brown',
#                  'Bryan Edwards',
#                  'Graham Gano',
#                  'Tyler Bass',
#                  'Josh Lambo',
#                  'Anthony Firkser',
#                  'Titans D/ST'],
#      'positions': [3, 3, 2, 1, 4, 16, 3, 2, 1, 2, 3, 5, 5, 5, 4, 16]},
#  2: {'players': ['Austin Ekeler',
#                  'Justin Jefferson',
#                  "D'Andre Swift",
#                  'Lamar Jackson',
#                  'Courtland Sutton',
#                  'Tyler Boyd',
#                  'Jamaal Williams',
#                  'Zack Moss',
#                  'Hunter Henry',
#                  'Justin Fields',
#                  "Ty'Son Williams",
#                  'Amon-Ra St. Brown',
#                  'Colts D/ST',
#                  'Juwan Johnson',
#                  'Rashod Bateman',
#                  'Ryan Succop'],
#      'positions': [2, 3, 2, 1, 3, 3, 2, 2, 4, 1, 2, 3, 16, 4, 3, 5]},
#  3: {'players': ['Najee Harris',
#                  'Clyde Edwards-Helaire',
#                  'Gus Edwards',
#                  'Chris Godwin',
#                  'DeVonta Smith',
#                  'Chase Claypool',
#                  'DJ Chark Jr.',
#                  'Devin Singletary',
#                  'Tyler Higbee',
#                  'Matt Ryan',
#                  'Mac Jones',
#                  'Gerald Everett',
#                  'Kadarius Toney',
#                  'Marquez Valdes-Scantling',
#                  'Rodrigo Blankenship',
#                  'Chargers D/ST'],
#      'positions': [2, 2, 2, 3, 3, 3, 3, 2, 4, 1, 1, 4, 3, 3, 5, 16]},
#  4: {'players': ['Dak Prescott',
#                  'DeAndre Hopkins',
#                  'JuJu Smith-Schuster',
#                  'Kyle Pitts',
#                  'Nyheim Hines',
#                  'Leonard Fournette',
#                  'Ravens D/ST',
#                  'Antonio Brown',
#                  'Harrison Butker',
#                  'Nelson Agholor',
#                  'Ben Roethlisberger',
#                  'Randall Cobb',
#                  'Vikings D/ST',
#                  'Matt Prater',
#                  'Cordarrelle Patterson',
#                  'Daniel Jones'],
#      'positions': [1, 3, 3, 4, 2, 2, 16, 3, 5, 3, 1, 3, 16, 5, 2, 1]},
#  5: {'players': ['Saquon Barkley',
#                  'A.J. Brown',
#                  'Miles Sanders',
#                  'DJ Moore',
#                  'Kenny Golladay',
#                  'William Fuller V',
#                  'Jonnu Smith',
#                  'Joe Burrow',
#                  'Jalen Reagor',
#                  'Rob Gronkowski',
#                  'Evan Engram',
#                  'Broncos D/ST',
#                  'Matt Gay',
#                  'Ty Johnson',
#                  'Salvon Ahmed',
#                  'Christian Kirk'],
#      'positions': [2, 3, 2, 3, 3, 3, 4, 1, 3, 4, 4, 16, 5, 2, 2, 3]},
#  6: {'players': ['Nick Chubb',
#                  'Joe Mixon',
#                  'Tyler Lockett',
#                  'Diontae Johnson',
#                  'Raheem Mostert',
#                  'Odell Beckham Jr.',
#                  'Tom Brady',
#                  'James White',
#                  'Austin Hooper',
#                  'Tony Pollard',
#                  'Trey Lance',
#                  'Emmanuel Sanders',
#                  'Mark Ingram II',
#                  'Devontae Booker',
#                  'Chase McLaughlin',
#                  'Bears D/ST'],
#      'positions': [2, 2, 3, 3, 2, 3, 1, 2, 4, 2, 1, 3, 2, 2, 5, 16]},
#  7: {'players': ['Aaron Jones',
#                  'Keenan Allen',
#                  'Adam Thielen',
#                  'Javonte Williams',
#                  'Russell Wilson',
#                  'Dallas Goedert',
#                  'Marvin Jones Jr.',
#                  'Ronald Jones II',
#                  'Tyrell Williams',
#                  'Giovani Bernard',
#                  'Jason Sanders',
#                  'Patriots D/ST',
#                  'Sammy Watkins',
#                  'Wayne Gallman II',
#                  'Allen Lazard',
#                  'DeSean Jackson'],
#      'positions': [2, 3, 3, 2, 1, 4, 3, 2, 3, 2, 5, 16, 3, 2, 3, 3]},
#  8: {'players': ['Davante Adams',
#                  'Calvin Ridley',
#                  'Amari Cooper',
#                  'Kareem Hunt',
#                  'Logan Thomas',
#                  "Ja'Marr Chase",
#                  'Melvin Gordon III',
#                  'AJ Dillon',
#                  'Baker Mayfield',
#                  'Rhamondre Stevenson',
#                  'Cole Kmet',
#                  '49ers D/ST',
#                  'Greg Zuerlein',
#                  'Damien Williams',
#                  'Jaret Patterson',
#                  'Van Jefferson'],
#      'positions': [3, 3, 3, 2, 4, 3, 2, 2, 1, 2, 4, 16, 5, 2, 2, 3]},
#  9: {'players': ['Dalvin Cook',
#                  'Allen Robinson II',
#                  'Chris Carson',
#                  'T.J. Hockenson',
#                  'Justin Herbert',
#                  'Mike Williams',
#                  'Marquez Callaway',
#                  'Steelers D/ST',
#                  'DeVante Parker',
#                  'Jamison Crowder',
#                  'Brandon McManus',
#                  'Dee Eskridge',
#                  'Rashaad Penny',
#                  'Boston Scott',
#                  'Darius Slayton',
#                  'James Washington'],
#      'positions': [2, 3, 2, 4, 1, 3, 3, 16, 3, 3, 5, 3, 2, 2, 3, 3]},
#  10: {'players': ['Derrick Henry',
#                   'George Kittle',
#                   'David Montgomery',
#                   'Brandon Aiyuk',
#                   'Michael Thomas',
#                   'Corey Davis',
#                   'Jaylen Waddle',
#                   'Darnell Mooney',
#                   'Washington D/ST',
#                   'Jameis Winston',
#                   'Tevin Coleman',
#                   'Zach Ertz',
#                   'Dolphins D/ST',
#                   'Ryan Fitzpatrick',
#                   'Mason Crosby',
#                   'Joshua Palmer'],
#       'positions': [2, 4, 2, 3, 3, 3, 3, 3, 16, 1, 2, 4, 16, 1, 5, 3]},
#  11: {'players': ['Christian McCaffrey',
#                   'Josh Jacobs',
#                   'Mike Evans',
#                   'Tee Higgins',
#                   'Kyler Murray',
#                   'Mike Gesicki',
#                   'Marquise Brown',
#                   'J.D. McKissic',
#                   'Michael Pittman Jr.',
#                   'Sterling Shepard',
#                   'Justin Jackson',
#                   'Browns D/ST',
#                   'Jared Cook',
#                   'Derek Carr',
#                   'Robbie Gould',
#                   'Hunter Renfrow'],
#       'positions': [2, 2, 3, 3, 1, 4, 3, 2, 3, 3, 2, 16, 4, 1, 5, 3]},
#  12: {'players': ['Ezekiel Elliott',
#                   'Patrick Mahomes',
#                   'Robert Woods',
#                   'Mark Andrews',
#                   'Sony Michel',
#                   'Deebo Samuel',
#                   'James Conner',
#                   'Mecole Hardman',
#                   'Bills D/ST',
#                   'Justin Tucker',
#                   'A.J. Green',
#                   'Gabriel Davis',
#                   'Latavius Murray',
#                   'Darrel Williams',
#                   'Samaje Perine',
#                   'Jared Goff'],
#       'positions': [2, 1, 3, 4, 2, 3, 2, 3, 16, 5, 3, 3, 2, 2, 2, 1]},
#  13: {'players': ['Stefon Diggs',
#                   'Antonio Gibson',
#                   'Julio Jones',
#                   'Myles Gaskin',
#                   'Matthew Stafford',
#                   'Laviska Shenault Jr.',
#                   'Trey Sermon',
#                   'Curtis Samuel',
#                   'Russell Gage',
#                   'Alexander Mattison',
#                   'Eric Ebron',
#                   'Kirk Cousins',
#                   "Tre'Quan Smith",
#                   'Daniel Carlson',
#                   'Giants D/ST',
#                   'Blake Jarwin'],
#       'positions': [3, 2, 3, 2, 1, 3, 2, 3, 3, 2, 4, 1, 3, 5, 16, 4]},
#  14: {'players': ['Alvin Kamara',
#                   'Terry McLaurin',
#                   'Josh Allen',
#                   'Robby Anderson',
#                   'Damien Harris',
#                   'Jarvis Landry',
#                   'Robert Tonyan',
#                   'David Johnson',
#                   'Jakobi Meyers',
#                   'Jason Myers',
#                   'Terrace Marshall Jr.',
#                   'Rams D/ST',
#                   'Chuba Hubbard',
#                   'Zach Wilson',
#                   'T.Y. Hilton',
#                   'Chris Conley'],
#       'positions': [2, 3, 1, 3, 2, 3, 4, 2, 3, 5, 3, 16, 2, 1, 3, 3]},
#  15: {'players': ['Jonathan Taylor',
#                   'Darren Waller',
#                   'Cooper Kupp',
#                   'Mike Davis',
#                   'Kenyan Drake',
#                   'Brandin Cooks',
#                   'Ryan Tannehill',
#                   'Henry Ruggs III',
#                   'Parris Campbell',
#                   'Trevor Lawrence',
#                   'Younghoe Koo',
#                   'Marlon Mack',
#                   'Saints D/ST',
#                   'Kenneth Gainwell',
#                   'Packers D/ST',
#                   'Adam Trautman'],
#       'positions': [2, 4, 3, 2, 2, 3, 1, 3, 3, 1, 5, 2, 16, 2, 16, 4]},
#  16: {'players': ['Travis Kelce',
#                   'James Robinson',
#                   'CeeDee Lamb',
#                   'Darrell Henderson Jr.',
#                   'Jerry Jeudy',
#                   'Michael Gallup',
#                   'Jalen Hurts',
#                   'Phillip Lindsay',
#                   'Elijah Moore',
#                   'Carlos Hyde',
#                   'Rondale Moore',
#                   'Nico Collins',
#                   'Panthers D/ST',
#                   'Dyami Brown',
#                   'Deshaun Watson',
#                   'Tristan Vizcaino'],
#       'positions': [4, 2, 3, 2, 3, 3, 1, 2, 3, 2, 3, 3, 16, 3, 1, 5]}}
